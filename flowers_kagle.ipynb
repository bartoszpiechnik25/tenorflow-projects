# %% [markdown]
# ## Flowers Classification
#
# Using dataset from kaggle containing 900 different kinds of flowers we are going to create model to correctly predict those classes.

# %%
import os
import zipfile
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

FLOWERS_PATH = os.path.join(os.getcwd(), 'data/flowers_dataset/')

# %% [markdown]
# #### Load and explore data

# %%
zip_path = os.path.join(os.getcwd(), 'data/archive.zip')
zip_file = zipfile.ZipFile(zip_path,'r')

zip_file.extractall(FLOWERS_PATH)
zip_file.close()
os.remove(zip_path)

# %%
flowers = pd.read_csv(os.path.join(FLOWERS_PATH, 'Flower_Table.csv'))

# %%
flowers.head()
# Out:
#   Flower group                                        Flower name  \
# 0     aeoniums                               Aeonium 'Mardi Gras'
# 1     aeoniums                           Aeonium (Aeonium nobile)
# 2     aeoniums  Variegated Pinwheel (Aeonium haworthii 'Varieg...
# 3     aeoniums                           Aeonium 'Jolly Clusters'
# 4     aeoniums                              Aeonium 'Emerald Ice'
#
#                                                  url  \
# 0  https://garden.org/plants/view/676815/Aeonium-...
# 1  https://garden.org/plants/view/117036/Aeonium-...
# 2  https://garden.org/plants/view/805995/Variegat...
# 3  https://garden.org/plants/view/806612/Aeonium-...
# 4  https://garden.org/plants/view/740710/Aeonium-...
#
#                                           Containers  \
# 0                   Needs excellent drainage in pots
# 1  Suitable in 3 gallon or larger, Needs excellen...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                            Flower Time Flowers  \
# 0  Late winter or early spring, Spring   Showy
# 1                       Spring, Summer   Showy
# 2                                  NaN   Showy
# 3                                  NaN   Showy
# 4                                  NaN   Showy
#
#                               Leaves Life cycle  \
# 0  Unusual foliage color, Variegated  Perennial
# 1                          Evergreen  Perennial
# 2                                NaN  Perennial
# 3                                NaN  Perennial
# 4              Evergreen, Variegated  Perennial
#
#                               Miscellaneous       Plant Habit  ...  \
# 0  Patent/Plant Breeders' Rights: USPP21407  Cactus/Succulent  ...
# 1           Tolerates poor soil, Monocarpic  Cactus/Succulent  ...
# 2                                       NaN  Cactus/Succulent  ...
# 3                                       NaN  Cactus/Succulent  ...
# 4  Patent/Plant Breeders' Rights: USPP27613  Cactus/Succulent  ...
#
#   Awards and Recognitions                      Parentage Child plants  \
# 0                     NaN                            NaN          NaN
# 1                     NaN                            NaN          NaN
# 2                 RHS AGM                            NaN          NaN
# 3                     NaN  Aeonium tabuliforme x Aeonium          NaN
# 4                     NaN        Sport of: Party Platter          NaN
#
#   Plant Height Fruit Minimum cold hardiness Propagation: Other methods  \
# 0          NaN   NaN                    NaN                        NaN
# 1          NaN   NaN                    NaN                        NaN
# 2          NaN   NaN                    NaN                        NaN
# 3          NaN   NaN                    NaN                        NaN
# 4          NaN   NaN                    NaN                        NaN
#
#   Propagation: Seeds Toxicity Bloom Size
# 0                NaN      NaN        NaN
# 1                NaN      NaN        NaN
# 2                NaN      NaN        NaN
# 3                NaN      NaN        NaN
# 4                NaN      NaN        NaN
#
# [5 rows x 29 columns]

# %%
flowers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Flower group                900 non-null    object
#  1   Flower name                 900 non-null    object
#  2   url                         900 non-null    object
#  3   Containers                  436 non-null    object
#  4   Flower Time                 554 non-null    object
#  5   Flowers                     643 non-null    object
#  6   Leaves                      493 non-null    object
#  7   Life cycle                  722 non-null    object
#  8   Miscellaneous               233 non-null    object
#  9   Plant Habit                 839 non-null    object
#  10  Resistances                 393 non-null    object
#  11  Soil pH Preferences         226 non-null    object
#  12  Suitable Locations          183 non-null    object
#  13  Sun Requirements            784 non-null    object
#  14  Uses                        651 non-null    object
#  15  Wildlife Attractant         509 non-null    object
#  16  Flower Color                508 non-null    object
#  17  Inflorescence Height        11 non-null     object
#  18  Plant Spread                410 non-null    object
#  19  Awards and Recognitions     84 non-null     object
#  20  Parentage                   88 non-null     object
#  21  Child plants                60 non-null     object
#  22  Plant Height                487 non-null    object
#  23  Fruit                       237 non-null    object
#  24  Minimum cold hardiness      391 non-null    object
#  25  Propagation: Other methods  481 non-null    object
#  26  Propagation: Seeds          483 non-null    object
#  27  Toxicity                    144 non-null    object
#  28  Bloom Size                  282 non-null    object
# dtypes: object(29)
# memory usage: 204.0+ KB

# %%
photos_path = os.path.join(FLOWERS_PATH, 'Flowers_Photo/')

def data_counter(path):
    """
    Counts images in each directory

    Args:
      -path (string): directory path containing images
    
    Returns:
      Dictionary containing directory names as keys and number of
      files in directory as values.
    """
    directory = os.listdir(path)
    values = {directory[i]: 0 for i in range(len(directory))}
    for folder in directory:
        folder_path = os.path.join(path, folder)
        for img in os.listdir(folder_path):
            img_path = os.path.join(folder_path, img)
            if os.path.getsize(img_path) == 0:
                os.remove(img_path)
            else:
                values[folder] += 1

    return values

num_flowers = sum(data_counter(photos_path).values())
print(f"Number of examples in dataset is: {num_flowers}")
# Out:
# Number of examples in dataset is: 21433

# %%
from PIL import Image
from random import sample

def print_size(dir):
    """
    Print size of random image from each directory

    Args:
      -dir (string): directory path containing images
    
    Returns:
      None
    """
    for directory in os.listdir(dir):
        directory_path = os.path.join(dir, directory)
        image_p = sample(os.listdir(directory_path), 1)[0]
        image = Image.open(os.path.join(directory_path, image_p))
        print(f"Random image size from {directory} directory is: {image.size, image.mode}")


print_size(photos_path)
# Out:
# Random image size from Winter Honeysuckle (Lonicera fragrantissima) directory is: ((250, 250), 'RGB')
# Random image size from Carrot (Daucus carota subsp. sativus 'Ultimate Hybrid') directory is: ((250, 250), 'RGB')
# Random image size from Butterwort (Pinguicula moctezumae) directory is: ((250, 250), 'RGB')
# Random image size from Sweet Potato (Ipomoea batatas Sweet Caroline Sweetheart Jet Black╬ô├ñ├│) directory is: ((250, 250), 'RGB')
# Random image size from Smoketrees (Cotinus coggygria) directory is: ((250, 250), 'RGB')
# Random image size from Cantaloupes (Cucumis melo) directory is: ((250, 250), 'RGB')
# Random image size from Garlic (Allium sativum 'Georgian Crystal') directory is: ((250, 250), 'RGB')
# Random image size from Astilbe 'Fanal' directory is: ((250, 250), 'RGB')
# Random image size from Leeks (Allium ampeloprasum) directory is: ((250, 250), 'RGB')
# Random image size from Western Red Cedar (Thuja plicata 'Whipcord') directory is: ((250, 250), 'RGB')
# Random image size from Pumpkin (Cucurbita pepo 'Winter Luxury Pie') directory is: ((250, 250), 'RGB')
# Random image size from Echeveria (Echeveria runyonii) directory is: ((250, 250), 'RGB')
# Random image size from Radish (Raphanus sativus 'Early Scarlet Globe') directory is: ((250, 250), 'RGB')
# Random image size from Purple Basil (Ocimum basilicum 'Purple Delight') directory is: ((250, 250), 'RGB')
# Random image size from Dahlia 'AC Sadie' directory is: ((250, 250), 'RGB')
# Random image size from Onion (Allium cepa 'Red River F1') directory is: ((250, 250), 'RGB')
# Random image size from Strawberries (Fragaria) directory is: ((250, 250), 'RGB')
# Random image size from American Cranberrybush Viburnum (Viburnum opulus var. americanum) directory is: ((250, 250), 'RGB')
# Random image size from Morning Glory (Ipomoea 'Split Second') directory is: ((250, 250), 'RGB')
# Random image size from Morning Glory (Ipomoea nil 'Kikyo Snowflakes') directory is: ((250, 250), 'RGB')
# Random image size from Apricot (Prunus armeniaca 'Gold Kist') directory is: ((250, 250), 'RGB')
# Random image size from Aeonium 'Mardi Gras' directory is: ((250, 250), 'RGB')
# Random image size from Dwarf Caladium (Caladium humboldtii) directory is: ((250, 250), 'RGB')
# Random image size from Chinese Wisteria (Wisteria sinensis 'Prolific') directory is: ((250, 250), 'RGB')
# Random image size from Peach (Prunus persica Flamin' FuryΓö¼┬½ PF-24C) directory is: ((250, 250), 'RGB')
# Random image size from Wild Bergamot (Monarda fistulosa) directory is: ((250, 250), 'RGB')
# Random image size from Biznaga de Otero (Mammillaria oteroi) directory is: ((250, 250), 'RGB')
# Random image size from Russian Sage (Perovskia atriplicifolia) directory is: ((250, 250), 'RGB')
# Random image size from Mock Orange (Philadelphus 'Innocence') directory is: ((250, 250), 'RGB')
# Random image size from Butterhead Lettuce (Lactuca sativa 'Tom Thumb') directory is: ((250, 250), 'RGB')
# Random image size from Chinese Dogwood (Cornus kousa subsp. chinensis 'Milky Way') directory is: ((250, 250), 'RGB')
# Random image size from Hardy Geranium (Geranium sanguineum 'Elke') directory is: ((250, 250), 'RGB')
# Random image size from Lilac (Syringa vulgaris 'Belle de Nancy') directory is: ((250, 250), 'RGB')
# Random image size from Hot Pepper (Capsicum baccatum 'Brazilian Starfish') directory is: ((250, 250), 'RGB')
# Random image size from Winter Squash (Cucurbita maxima 'Buttercup') directory is: ((250, 250), 'RGB')
# Random image size from Cheddar Pink (Dianthus gratianopolitanus BluKiss╬ô├ñ├│) directory is: ((250, 250), 'RGB')
# Random image size from Cucumber (Cucumis sativus 'Artist') directory is: ((250, 250), 'RGB')
# Random image size from Smoke Tree (Cotinus coggygria 'Royal Purple') directory is: ((250, 250), 'RGB')
# Random image size from Common Jujube (Ziziphus jujuba 'Lang') directory is: ((250, 250), 'RGB')
# Random image size from Yarrow (Achillea millefolium 'Summer Pastels') directory is: ((250, 250), 'RGB')
# Random image size from Betony (Stachys spathulata) directory is: ((250, 250), 'RGB')
# Random image size from Cherry Plum (Prunus cerasifera 'Thundercloud') directory is: ((250, 250), 'RGB')
# Random image size from Foxtail Agave (Agave attenuata) directory is: ((250, 250), 'RGB')
# Random image size from Mexican Butterwort; Mexican Ping (Pinguicula ibarrae) directory is: ((250, 250), 'RGB')
# Random image size from Wild Indigo (Baptisia 'Pink Lemonade') directory is: ((250, 250), 'RGB')
# Random image size from Sand Lettuce (Dudleya caespitosa) directory is: ((250, 250), 'RGB')
# Random image size from Swiss Chard (Beta vulgaris subsp. cicla 'Ruby Red') directory is: ((250, 250), 'RGB')
# Random image size from Butterfly Bush (Buddleja 'Orange Sceptre') directory is: ((250, 250), 'RGB')
# Random image size from Creeping Phlox (Phlox subulata 'Emerald Blue') directory is: ((250, 250), 'RGB')
# Random image size from Popcorn (Zea mays subsp. mays 'Glass Gem') directory is: ((250, 250), 'RGB')
# Random image size from Hosta 'Liberty' directory is: ((250, 250), 'RGB')
# Random image size from Rose (Rosa 'Institut Lumiere') directory is: ((250, 250), 'RGB')
# Random image size from Common Fig (Ficus carica 'Jolly Tiger') directory is: ((250, 250), 'RGB')
# Random image size from Catmint (Nepeta Cat's Meow) directory is: ((250, 250), 'RGB')
# Random image size from Dahlia 'Creme de Cassis' directory is: ((250, 250), 'RGB')
# Random image size from Bleeding Heart (Lamprocapnos spectabilis) directory is: ((250, 250), 'RGB')
# Random image size from Japanese Cucumber (Cucumis sativus 'Southern Delight') directory is: ((250, 250), 'RGB')
# Random image size from Geraniums (Geranium) directory is: ((250, 250), 'RGB')
# Random image size from Peony (Paeonia 'Athena') directory is: ((250, 250), 'RGB')
# Random image size from Dahlias (Dahlia) directory is: ((250, 250), 'RGB')
# Random image size from Japanese Honeysuckle (Lonicera japonica 'Halliana') directory is: ((250, 250), 'RGB')
# Random image size from Double Daffodil (Narcissus 'Tahiti') directory is: ((250, 250), 'RGB')
# Random image size from Orange (Citrus reticulata 'Satsuma') directory is: ((250, 250), 'RGB')
# Random image size from Nectarine (Prunus persica 'Arctic Glo') directory is: ((250, 250), 'RGB')
# Random image size from Dill (Anethum graveolens 'Fernleaf') directory is: ((250, 250), 'RGB')
# Random image size from Sweet Cherry (Prunus avium 'Bing') directory is: ((250, 250), 'RGB')
# Random image size from Butterwort (Pinguicula cyclosecta) directory is: ((250, 250), 'RGB')
# Random image size from Mexican Dogwood (Cornus florida var. urbiniana) directory is: ((250, 250), 'RGB')
# Random image size from Rhubarb (Rheum 'Glaskins Perpetual') directory is: ((250, 250), 'RGB')
# Random image size from Coreopsis Li'l Bang╬ô├ñ├│ Darling Clementine directory is: ((250, 250), 'RGB')
# Random image size from Carrot (Daucus carota subsp. sativus 'Atomic Red') directory is: ((250, 250), 'RGB')
# Random image size from Itoh Peony (Paeonia 'Caroline Constabel') directory is: ((250, 250), 'RGB')
# Random image size from Lacecap Hydrangea (Hydrangea macrophylla Endless SummerΓö¼┬½ Twist-n-ShoutΓö¼┬½) directory is: ((250, 250), 'RGB')
# Random image size from Petunia CrazytuniaΓö¼┬½ Cosmic Pink directory is: ((250, 250), 'RGB')
# Random image size from White Texas Star Hibiscus (Hibiscus coccineus 'Alba') directory is: ((250, 250), 'RGB')
# Random image size from Veronica (Veronica longifolia) directory is: ((250, 250), 'RGB')
# Random image size from Basil (Ocimum basilicum 'Cardinal') directory is: ((250, 250), 'RGB')
# Random image size from Aloe 'Orange Marmalade' directory is: ((250, 250), 'RGB')
# Random image size from Eggplant (Solanum melongena 'Icicle') directory is: ((250, 250), 'RGB')
# Random image size from Baby's Breaths (Gypsophila elegans) directory is: ((250, 250), 'RGB')
# Random image size from Daffodil (Narcissus 'Lavender Bell') directory is: ((250, 250), 'RGB')
# Random image size from African Blue Basil (Ocimum 'African Blue') directory is: ((250, 250), 'RGB')
# Random image size from Arborvitae (Thuja 'Green Giant') directory is: ((250, 250), 'RGB')
# Random image size from Japanese Morning Glory (Ipomoea nil) directory is: ((250, 250), 'RGB')
# Random image size from Dutch Hyacinth (Hyacinthus orientalis 'Delft Blue') directory is: ((250, 250), 'RGB')
# Random image size from Echeveria (Echeveria affinis 'Black Knight') directory is: ((250, 250), 'RGB')
# Random image size from Cucumber (Cucumis sativus 'Lemon') directory is: ((250, 250), 'RGB')
# Random image size from Echeveria 'Rain Drops' directory is: ((250, 250), 'RGB')
# Random image size from Potato (Solanum tuberosum 'Red Pontiac') directory is: ((250, 250), 'RGB')
# Random image size from Aeoniums (Aeonium) directory is: ((250, 250), 'RGB')
# Random image size from Saturn Peach (Prunus persica 'Saturn') directory is: ((250, 250), 'RGB')
# Random image size from Biznaga de Isla Pichilingue (Mammillaria albicans subsp. fraileana) directory is: ((250, 250), 'RGB')
# Random image size from Cheddar Pink (Dianthus Dessert╬ô├ñ├│ Raspberry Swirl) directory is: ((250, 250), 'RGB')
# Random image size from Miniature Jonquilla Daffodil (Narcissus 'Pipit') directory is: ((250, 250), 'RGB')
# Random image size from Clustered Bellflower (Campanula glomerata) directory is: ((250, 250), 'RGB')
# Random image size from Spinach (Spinacia oleracea 'America') directory is: ((250, 250), 'RGB')
# Random image size from Mints (Mentha) directory is: ((250, 250), 'RGB')
# Random image size from Crape Myrtle (Lagerstroemia indica Red RocketΓö¼┬½) directory is: ((250, 250), 'RGB')
# Random image size from Althea (Hibiscus syriacus Blueberry Smoothie╬ô├ñ├│) directory is: ((250, 250), 'RGB')
# Random image size from Coppertone Stonecrop (Sedum nussbaumerianum 'Shooting Stars') directory is: ((250, 250), 'RGB')
# Random image size from Flowering Cabbage (Brassica oleracea var. viridis Pigeon╬ô├ñ├│ White) directory is: ((250, 250), 'RGB')
# Random image size from Baby Burro's Tail (Sedum burrito) directory is: ((250, 250), 'RGB')
# Random image size from Purple-flowering raspberry (Rubus odoratus) directory is: ((250, 250), 'RGB')
# Random image size from Butterwort (Pinguicula esseriana) directory is: ((250, 250), 'RGB')
# Random image size from Larkspur (Delphinium elatum 'Guardian Lavender') directory is: ((250, 250), 'RGB')
# Random image size from White Dead Nettle (Lamium album) directory is: ((250, 250), 'RGB')
# Random image size from Coral Bells (Heuchera 'Mega Caramel') directory is: ((250, 250), 'RGB')
# Random image size from Elfin Thyme (Thymus serpyllum 'Elfin') directory is: ((250, 250), 'RGB')
# Random image size from Eastern Dogwood (Cornus florida var. florida Cherokee Brave╬ô├ñ├│) directory is: ((250, 250), 'RGB')
# Random image size from Thornless Blackberry (Rubus 'Arapaho') directory is: ((250, 250), 'RGB')
# Random image size from Caraway Thyme (Thymus herba-barona) directory is: ((250, 250), 'RGB')
# Random image size from Japanese Crepe Myrtle (Lagerstroemia fauriei 'Fantasy') directory is: ((250, 250), 'RGB')
# Random image size from Eastern Ninebark (Physocarpus opulifolius DiaboloΓö¼┬½) directory is: ((250, 250), 'RGB')
# Random image size from Shasta Daisy (Leucanthemum x superbum 'Becky') directory is: ((250, 250), 'RGB')
# Random image size from Coral Bells (Heuchera micrantha 'Palace Purple') directory is: ((250, 250), 'RGB')
# Random image size from Red Twig Dogwood (Cornus sanguinea 'Anny's Winter Orange') directory is: ((250, 250), 'RGB')
# Random image size from Sweet Potato Vine (Ipomoea batatas 'Pink Frost') directory is: ((250, 250), 'RGB')
# Random image size from Bleeding Hearts (Lamprocapnos) directory is: ((250, 250), 'RGB')
# Random image size from Hyacinths (Hyacinthus) directory is: ((250, 250), 'RGB')
# Random image size from Meadow Blazing Star (Liatris ligulistylis) directory is: ((250, 250), 'RGB')
# Random image size from Jelly Bean (Sedum x rubrotinctum) directory is: ((250, 250), 'RGB')
# Random image size from Strawberry (Fragaria x ananassa) directory is: ((250, 250), 'RGB')
# Random image size from Coneflower (Echinacea Big Sky╬ô├ñ├│ Sundown) directory is: ((250, 250), 'RGB')
# Random image size from Radish (Raphanus sativus 'Champion') directory is: ((250, 250), 'RGB')
# Random image size from Spinach (Spinacia oleracea 'Ashley') directory is: ((250, 250), 'RGB')
# Random image size from Oreganos (Origanum vulgare) directory is: ((250, 250), 'RGB')
# Random image size from Common Fig (Ficus carica 'Brown Turkey') directory is: ((250, 250), 'RGB')
# Random image size from Beet (Beta vulgaris 'Camaro') directory is: ((250, 250), 'RGB')
# Random image size from Gooseberry (Ribes uva-crispa 'Hinnonmaki Rod') directory is: ((250, 250), 'RGB')
# Random image size from Apples (Malus) directory is: ((250, 250), 'RGB')
# Random image size from Beach Morning Glory (Ipomoea pes-caprae) directory is: ((250, 250), 'RGB')
# Random image size from Turnip (Brassica rapa subsp. rapa 'White Lady') directory is: ((250, 250), 'RGB')
# Random image size from Coral Bells (Heuchera 'Silver Scrolls') directory is: ((250, 250), 'RGB')
# Random image size from Romaine (Lactuca sativa 'Willow') directory is: ((250, 250), 'RGB')
# Random image size from Sargent's Crabapple (Malus sieboldii subsp. sieboldii 'Roselow') directory is: ((250, 250), 'RGB')
# Random image size from Delphinium 'Blue Dawn' directory is: ((250, 250), 'RGB')
# Random image size from Cilantros (Coriandrum sativum) directory is: ((250, 250), 'RGB')
# Random image size from Dianthus (Dianthus longicalyx) directory is: ((250, 250), 'RGB')
# Random image size from Lemon Bee Balm (Monarda citriodora) directory is: ((250, 250), 'RGB')
# Random image size from Mealy Cup Sage (Salvia farinacea CathedralΓö¼┬½ Shining Seas) directory is: ((250, 250), 'RGB')
# Random image size from Eastern Ninebark (Physocarpus opulifolius 'Center Glow') directory is: ((250, 250), 'RGB')
# Random image size from Echeveria 'Blue Wren' directory is: ((250, 250), 'RGB')
# Random image size from Shasta Daisies (Leucanthemum x superbum) directory is: ((250, 250), 'RGB')
# Random image size from Eggplant (Solanum melongena 'Southern Pink') directory is: ((250, 250), 'RGB')
# Random image size from Dalmatian Bellflower (Campanula portenschlagiana) directory is: ((250, 250), 'RGB')
# Random image size from Pacific Coast Iris (Iris 'Finger Pointing') directory is: ((250, 250), 'RGB')
# Random image size from Gaillardia 'Punch Bowl' directory is: ((250, 250), 'RGB')
# Random image size from Common Fig (Ficus carica 'Chicago Hardy') directory is: ((250, 250), 'RGB')
# Random image size from Turnip (Brassica rapa subsp. rapa 'Round Red') directory is: ((250, 250), 'RGB')
# Random image size from Hydrangea (Hydrangea quercifolia 'Munchkin') directory is: ((250, 250), 'RGB')
# Random image size from Vietnamese Gardenia (Gardenia vietnamensis) directory is: ((250, 250), 'RGB')
# Random image size from Jujube (Ziziphus jujuba 'Sherwood') directory is: ((250, 250), 'RGB')
# Random image size from Spirea (Spiraea nipponica 'Snowmound') directory is: ((250, 250), 'RGB')
# Random image size from Larkspur (Delphinium 'Benary's Pacific Cameliard') directory is: ((250, 250), 'RGB')
# Random image size from Butterwort (Pinguicula agnata) directory is: ((250, 250), 'RGB')
# Random image size from Dianthus directory is: ((250, 250), 'RGB')
# Random image size from Crinum Lily (Crinum 'Stars and Stripes') directory is: ((250, 250), 'RGB')
# Random image size from Pea (Pisum sativum 'Spring Blush') directory is: ((250, 250), 'RGB')
# Random image size from Hydrangea (Hydrangea macrophylla L.A. Dreamin'╬ô├ñ├│ Lindsey Ann) directory is: ((250, 250), 'RGB')
# Random image size from Feather Cactus (Mammillaria plumosa) directory is: ((250, 250), 'RGB')
# Random image size from Hibiscus (Hibiscus moscheutos Summerific╬ô├ñ├│ Summer Storm) directory is: ((250, 250), 'RGB')
# Random image size from Flowering Dogwood (Cornus florida) directory is: ((250, 250), 'RGB')
# Random image size from Thornless Blackberry (Rubus 'Apache') directory is: ((250, 250), 'RGB')
# Random image size from Coral Bells (Heuchera DolceΓö¼┬½ Blackberry Ice) directory is: ((250, 250), 'RGB')
# Random image size from Bleeding Heart (Lamprocapnos spectabilis Valentine╬ô├ñ├│) directory is: ((250, 250), 'RGB')
# Random image size from Tomato (Solanum lycopersicum 'Helsing Junction Blues') directory is: ((250, 250), 'RGB')
# Random image size from Rose of Sharon (Hibiscus syriacus 'Danica') directory is: ((250, 250), 'RGB')
# Random image size from Yarrow (Achillea 'Summer Berries') directory is: ((250, 250), 'RGB')
# Random image size from Crinum 'Marisco' directory is: ((250, 250), 'RGB')
# Random image size from Lettuce (Lactuca sativa 'Red Romaine') directory is: ((250, 250), 'RGB')
# Random image size from American Beautyberry (Callicarpa americana) directory is: ((250, 250), 'RGB')
# Random image size from Flowering Dogwood (Cornus Stellar PinkΓö¼┬½) directory is: ((250, 250), 'RGB')
# Random image size from Lily (Lilium pyrenaicum) directory is: ((250, 250), 'RGB')
# Random image size from Geranium (Geranium wallichianum 'Crystal Lake') directory is: ((250, 250), 'RGB')
# Random image size from Compact Queen Victoria Agave (Agave victoriae-reginae subsp. swobodae) directory is: ((250, 250), 'RGB')
# Random image size from Rose (Rosa 'Ebb Tide') directory is: ((250, 250), 'RGB')
# Random image size from Basil (Ocimum basilicum 'Emily') directory is: ((250, 250), 'RGB')
# Random image size from Pacific Coast Iris (Iris 'Big Waves') directory is: ((250, 250), 'RGB')
# Random image size from Hen and Chicks (Sempervivum tectorum 'Grammens') directory is: ((250, 250), 'RGB')
# Random image size from Sweet Potatoes (Ipomoea batatas) directory is: ((250, 250), 'RGB')
# Random image size from Dogwoods (Cornus) directory is: ((250, 250), 'RGB')
# Random image size from Okra (Abelmoschus esculentus 'Jambalaya') directory is: ((250, 250), 'RGB')
# Random image size from Tropical Milkweed (Asclepias curassavica) directory is: ((250, 250), 'RGB')
# Random image size from Kaibab Agave (Agave utahensis subsp. kaibabensis) directory is: ((250, 250), 'RGB')
# Random image size from Hyacinth (Hyacinthus orientalis 'Blue Jacket') directory is: ((250, 250), 'RGB')
# Random image size from Oleander (Nerium oleander 'Hardy White') directory is: ((250, 250), 'RGB')
# Random image size from Jerusalem Artichoke (Helianthus tuberosus 'Clearwater') directory is: ((250, 250), 'RGB')
# Random image size from Lambs' Ears (Stachys byzantina) directory is: ((250, 250), 'RGB')
# Random image size from Petunias (Petunia) directory is: ((250, 250), 'RGB')
# Random image size from Daylily (Hemerocallis 'Soli Deo Gloria') directory is: ((250, 250), 'RGB')
# Random image size from Daylily (Hemerocallis 'Kathrine Carter') directory is: ((250, 250), 'RGB')
# Random image size from Fern Leaf Peony (Paeonia tenuifolia) directory is: ((250, 250), 'RGB')
# Random image size from Rhododendrons (Rhododendron) directory is: ((250, 250), 'RGB')
# Random image size from Crepe Myrtle (Lagerstroemia 'Ebony Flame') directory is: ((250, 250), 'RGB')
# Random image size from Chinese rhubarb (Rheum palmatum 'Bowles Crimson') directory is: ((250, 250), 'RGB')
# Random image size from Figs (Ficus carica) directory is: ((250, 250), 'RGB')
# Random image size from Amazon Jungle Vine (Vitis amazonica) directory is: ((250, 250), 'RGB')
# Random image size from Shasta Daisy (Leucanthemum x superbum 'White Breeze') directory is: ((250, 250), 'RGB')
# Random image size from Dahlia 'Destiny's John Michael' directory is: ((250, 250), 'RGB')
# Random image size from Butterfly Bush (Buddleja davidii Buzz╬ô├ñ├│ Ivory) directory is: ((250, 250), 'RGB')
# Random image size from Iceland Poppy (Papaver nudicaule 'Champagne Bubbles White') directory is: ((250, 250), 'RGB')
# Random image size from Rose (Rosa 'Wife of Bath') directory is: ((250, 250), 'RGB')
# Random image size from St.Christopher Lily (Crinum jagus) directory is: ((250, 250), 'RGB')
# Random image size from Blackberry (Rubus 'Black Satin') directory is: ((250, 250), 'RGB')
# Random image size from Culinary Sages (Salvia officinalis) directory is: ((250, 250), 'RGB')
# Random image size from Bolivian Hummingbird Sage (Salvia oxyphora) directory is: ((250, 250), 'RGB')
# Random image size from Bumpy Convolvulaceae (Ipomoea tuberculata) directory is: ((250, 250), 'RGB')
# Random image size from Hen and Chicks (Sempervivum 'Red Lion') directory is: ((250, 250), 'RGB')
# Random image size from Potato (Solanum tuberosum 'Vitelotte') directory is: ((250, 250), 'RGB')
# Random image size from Beet (Beta vulgaris 'Boro') directory is: ((250, 250), 'RGB')
# Random image size from Canna CannaSol╬ô├ñ├│ Lily directory is: ((250, 250), 'RGB')
# Random image size from Jerusalem Artichoke (Helianthus tuberosus 'Stampede') directory is: ((250, 250), 'RGB')
# Random image size from Holy Basil (Ocimum tenuiflorum 'Green Sacred') directory is: ((250, 250), 'RGB')
# Random image size from French Tarragon (Artemisia dracunculus 'Sativa') directory is: ((250, 250), 'RGB')
# Random image size from Eastern Ninebark (Physocarpus opulifolius Coppertina╬ô├ñ├│) directory is: ((250, 250), 'RGB')
# Random image size from Hardy Hibiscus (Hibiscus moscheutos Summerific╬ô├ñ├│ Starry Starry Night) directory is: ((250, 250), 'RGB')
# Random image size from Carrot (Daucus carota subsp. sativus 'Burpees A#1') directory is: ((250, 250), 'RGB')
# Random image size from Wisterias (Wisteria) directory is: ((250, 250), 'RGB')
# Random image size from Foxglove (Digitalis purpurea) directory is: ((250, 250), 'RGB')
# Random image size from Variegated Pinwheel (Aeonium haworthii 'Variegatum') directory is: ((250, 250), 'RGB')
# Random image size from Spotted Dead Nettle (Lamium maculatum) directory is: ((250, 250), 'RGB')
# Random image size from Beet (Beta vulgaris 'Solo') directory is: ((250, 250), 'RGB')
# Random image size from White Stonecrop (Sedum album 'Twickel Purple') directory is: ((250, 250), 'RGB')
# Random image size from Willow Leaf Foxglove (Digitalis obscura) directory is: ((250, 250), 'RGB')
# Random image size from Jonquilla Narcissus (Narcissus 'Blushing Lady') directory is: ((250, 250), 'RGB')
# Random image size from Lewis' Mockorange (Philadelphus lewisii) directory is: ((250, 250), 'RGB')
# Random image size from Bellflower (Campanula Fancy MeeΓö¼┬½) directory is: ((250, 250), 'RGB')
# Random image size from Dill (Anethum graveolens 'Bouquet') directory is: ((250, 250), 'RGB')
# Random image size from Peony (Paeonia lactiflora 'Bowl of Beauty') directory is: ((250, 250), 'RGB')
# Random image size from Cabbage (Brassica oleracea var. capitata 'Deep Blue') directory is: ((250, 250), 'RGB')
# Random image size from Koreanspice Viburnum (Viburnum carlesii) directory is: ((250, 250), 'RGB')
# Random image size from Carrot (Daucus carota subsp. sativus 'Purple 68') directory is: ((250, 250), 'RGB')
# Random image size from Bigleaf Hydrangea (Hydrangea macrophylla Gentian Dome) directory is: ((250, 250), 'RGB')
# Random image size from Wild Blue Phlox (Phlox divaricata) directory is: ((250, 250), 'RGB')
# Random image size from Rhubarb (Rheum rhabarbarum) directory is: ((250, 250), 'RGB')
# Random image size from Black Eyed Susan (Rudbeckia fulgida var. sullivantii 'Goldsturm') directory is: ((250, 250), 'RGB')
# Random image size from Tickseed (Coreopsis grandiflora 'Sunkiss') directory is: ((250, 250), 'RGB')
# Random image size from Coneflower (Echinacea purpurea 'Green Twister') directory is: ((250, 250), 'RGB')
# Random image size from Scallop Squash (Cucurbita pepo 'Early White Bush Scallop') directory is: ((250, 250), 'RGB')
# Random image size from False Goat's Beard (Astilbe Younique Cerise╬ô├ñ├│) directory is: ((250, 250), 'RGB')
# Random image size from Grape (Vitis vinifera 'Gamay') directory is: ((250, 250), 'RGB')
# Random image size from Blanket Flower (Gaillardia) directory is: ((250, 250), 'RGB')
# Random image size from Oleander (Nerium oleander 'Calypso') directory is: ((250, 250), 'RGB')
# Random image size from Melon (Cucumis melo 'Charentais') directory is: ((250, 250), 'RGB')
# Random image size from Rainbow Carrot (Daucus carota subsp. sativus 'Rainbow') directory is: ((250, 250), 'RGB')
# Random image size from Rhododendron 'Roseum Elegans' directory is: ((250, 250), 'RGB')
# Random image size from Garden Sage (Salvia officinalis 'Robert Grimm') directory is: ((250, 250), 'RGB')
# Random image size from Crinum 'Milk and Wine' directory is: ((250, 250), 'RGB')
# Random image size from Ornamental Gourd (Cucurbita pepo 'Tennessee Dancing') directory is: ((250, 250), 'RGB')
# Random image size from Bush Bean (Phaseolus vulgaris 'Topcrop') directory is: ((250, 250), 'RGB')
# Random image size from Blue Daisy (Felicia amelloides) directory is: ((250, 250), 'RGB')
# Random image size from Astilbe 'Icecream' directory is: ((250, 250), 'RGB')
# Random image size from White Currant (Ribes rubrum 'White Versailles') directory is: ((250, 250), 'RGB')
# Random image size from American Arborvitae (Thuja occidentalis 'Hetz Midget') directory is: ((250, 250), 'RGB')
# Random image size from Corn (Zea mays subsp. mays 'Jackpot') directory is: ((250, 250), 'RGB')
# Random image size from Gardenia (Gardenia jasminoides 'White Gem') directory is: ((250, 250), 'RGB')
# Random image size from Dune Aloe (Aloe thraskii) directory is: ((250, 250), 'RGB')
# Random image size from Triumph Tulip (Tulipa 'Jackpot') directory is: ((250, 250), 'RGB')
# Random image size from Poppies (Papaver) directory is: ((250, 250), 'RGB')
# Random image size from Possumhaw Holly (Ilex decidua) directory is: ((250, 250), 'RGB')
# Random image size from Bok Choy (Brassica rapa subsp. chinensis 'Joi Choi') directory is: ((250, 250), 'RGB')
# Random image size from Bellflower (Campanula rapunculus subsp. rapunculus) directory is: ((250, 250), 'RGB')
# Random image size from Spinaches (Spinacia oleracea) directory is: ((250, 250), 'RGB')
# Random image size from Petunia Headliner╬ô├ñ├│ Night Sky directory is: ((250, 250), 'RGB')
# Random image size from Shallot (Allium cepa 'Creme Brulee') directory is: ((250, 250), 'RGB')
# Random image size from Eggplant (Solanum melongena 'Bride') directory is: ((250, 250), 'RGB')
# Random image size from Potato (Solanum tuberosum 'Adirondack Blue') directory is: ((250, 250), 'RGB')
# Random image size from Crepe Myrtle (Lagerstroemia Pink VelourΓö¼┬½) directory is: ((250, 250), 'RGB')
# Random image size from Peach (Prunus persica 'Canadian Harmony') directory is: ((250, 250), 'RGB')
# Random image size from Sweet Cherries (Prunus avium) directory is: ((250, 250), 'RGB')
# Random image size from Carrot (Daucus carota subsp. sativus 'Envy') directory is: ((250, 250), 'RGB')
# Random image size from Triandrus Daffodil (Narcissus 'Thalia') directory is: ((250, 250), 'RGB')
# Random image size from Parsnip (Pastinaca sativa 'Hollow Crown') directory is: ((250, 250), 'RGB')
# Random image size from Common Lilac (Syringa vulgaris 'Arch McKean') directory is: ((250, 250), 'RGB')
# Random image size from Melon (Cucumis melo 'Kajari') directory is: ((250, 250), 'RGB')
# Random image size from Peony (Paeonia lactiflora 'Top Brass') directory is: ((250, 250), 'RGB')
# Random image size from Daylily (Hemerocallis 'Sons of Thunder') directory is: ((250, 250), 'RGB')
# Random image size from Sunroot (Helianthus tuberosus 'White Fuseau') directory is: ((250, 250), 'RGB')
# Random image size from Oleander (Nerium oleander 'Red Cardinal') directory is: ((250, 250), 'RGB')
# Random image size from Catmints (Nepeta) directory is: ((250, 250), 'RGB')
# Random image size from Ornamental Sweet Potato (Ipomoea batatas 'Blackie') directory is: ((250, 250), 'RGB')
# Random image size from Tall Bearded Iris (Iris 'Wonders Never Cease') directory is: ((250, 250), 'RGB')
# Random image size from Bulbocodium Daffodil (Narcissus 'Spoirot') directory is: ((250, 250), 'RGB')
# Random image size from Plumeria (Plumeria rubra 'Flaming Rock Dragon') directory is: ((250, 250), 'RGB')
# Random image size from Greigii Tulip (Tulipa 'Fire of Love') directory is: ((250, 250), 'RGB')
# Random image size from Hairy Beardtongue (Penstemon hirsutus) directory is: ((250, 250), 'RGB')
# Random image size from Garden Bells (Penstemon hartwegii Phoenix╬ô├ñ├│ Pink) directory is: ((250, 250), 'RGB')
# Random image size from Eastern Ninebark (Physocarpus opulifolius 'Dart's Gold') directory is: ((250, 250), 'RGB')
# Random image size from Chinese Astilbe (Astilbe rubra) directory is: ((250, 250), 'RGB')
# Random image size from Purple Coneflower (Echinacea purpurea 'Magnus') directory is: ((250, 250), 'RGB')
# Random image size from Black-eyed Susan (Rudbeckia hirta 'Cappuccino') directory is: ((250, 250), 'RGB')
# Random image size from Wild Indigo (Baptisia 'Brownie Points') directory is: ((250, 250), 'RGB')
# Random image size from Pepper (Capsicum 'Mad Hatter') directory is: ((250, 250), 'RGB')
# Random image size from Sedum (Sedum palmeri) directory is: ((250, 250), 'RGB')
# Random image size from Dry Bean (Phaseolus vulgaris 'Good Mother Stallard') directory is: ((250, 250), 'RGB')
# Random image size from Pencilled Cranesbill (Geranium versicolor) directory is: ((250, 250), 'RGB')
# Random image size from Common Bean (Phaseolus vulgaris 'Contender') directory is: ((250, 250), 'RGB')
# Random image size from Tomato (Solanum lycopersicum 'Buffalo Steak') directory is: ((250, 250), 'RGB')
# Random image size from Cutleaf Coneflower (Rudbeckia laciniata) directory is: ((250, 250), 'RGB')
# Random image size from Pachypodium (Pachypodium brevicaule) directory is: ((250, 250), 'RGB')
# Random image size from Lettuces (Lactuca sativa) directory is: ((250, 250), 'RGB')
# Random image size from Apple (Malus pumila 'Winter Pearmain') directory is: ((250, 250), 'RGB')
# Random image size from Triumph Tulip (Tulipa 'Aperitif') directory is: ((250, 250), 'RGB')
# Random image size from Henbit (Lamium amplexicaule) directory is: ((250, 250), 'RGB')
# Random image size from English Pea (Pisum sativum 'Green Arrow') directory is: ((250, 250), 'RGB')
# Random image size from Cantaloupe (Cucumis melo 'Ambrosia') directory is: ((250, 250), 'RGB')
# Random image size from Red Table Grape (Vitis labrusca 'Vanessa') directory is: ((250, 250), 'RGB')
# Random image size from Beebalm (Monarda didyma 'Marshall's Delight') directory is: ((250, 250), 'RGB')
# Random image size from Gardenia (Gardenia jasminoides 'Veitchii') directory is: ((250, 250), 'RGB')
# Random image size from Echeveria 'Afterglow' directory is: ((250, 250), 'RGB')
# Random image size from Hydrangeas (Hydrangea) directory is: ((250, 250), 'RGB')
# Random image size from Rusty Blackhaw Viburnum (Viburnum rufidulum) directory is: ((250, 250), 'RGB')
# Random image size from Garden Onion (Allium cepa 'Super Star') directory is: ((250, 250), 'RGB')
# Random image size from Lettuce (Lactuca sativa 'Yugoslavian Red Butterhead') directory is: ((250, 250), 'RGB')
# Random image size from Center Stripe Agave (Agave univittata 'Quadricolor') directory is: ((250, 250), 'RGB')
# Random image size from Aloes (Aloe) directory is: ((250, 250), 'RGB')
# Random image size from Asparagus (Asparagus officinalis) directory is: ((250, 250), 'RGB')
# Random image size from Daylily (Hemerocallis 'Vanishing Mist') directory is: ((250, 250), 'RGB')
# Random image size from Lady Tulip (Tulipa clusiana) directory is: ((250, 250), 'RGB')
# Random image size from Dutchman's Breeches (Dicentra cucullaria) directory is: ((250, 250), 'RGB')
# Random image size from Spotted Beebalm (Monarda punctata var. punctata) directory is: ((250, 250), 'RGB')
# Random image size from Coral Bells (Heuchera sanguinea 'Ruby Bells') directory is: ((250, 250), 'RGB')
# Random image size from Celery (Apium graveolens var. dulce 'Lathom Self Blanching Galaxy') directory is: ((250, 250), 'RGB')
# Random image size from Cranesbill (Geranium platypetalum) directory is: ((250, 250), 'RGB')
# Random image size from Nepeta (Nepeta x faassenii 'Select Blue') directory is: ((250, 250), 'RGB')
# Random image size from Shasta Daisy (Leucanthemum x superbum 'Snehurka') directory is: ((250, 250), 'RGB')
# Random image size from Tomato (Solanum lycopersicum 'Yellow Mortgage Lifter') directory is: ((250, 250), 'RGB')
# Random image size from Rhododendron 'Blue Peter' directory is: ((250, 250), 'RGB')
# Random image size from Dahlia 'Firepot' directory is: ((250, 250), 'RGB')
# Random image size from Corn (Zea mays subsp. mays) directory is: ((250, 250), 'RGB')
# Random image size from Hardy Hibiscus Hybrid (Hibiscus 'Summer in Paradise') directory is: ((250, 250), 'RGB')
# Random image size from Pumpkin (Cucurbita pepo 'Styrian Hulless') directory is: ((250, 250), 'RGB')
# Random image size from Bellflower (Campanula scheuchzeri) directory is: ((250, 250), 'RGB')
# Random image size from Thyme (Thymus praecox 'Highland Cream') directory is: ((250, 250), 'RGB')
# Random image size from Quiver Tree (Aloidendron dichotomum) directory is: ((250, 250), 'RGB')
# Random image size from Turnip (Brassica rapa subsp. rapa 'Purple Top White Globe') directory is: ((250, 250), 'RGB')
# Random image size from European Smoketree (Cotinus coggygria Winecraft BlackΓö¼┬½) directory is: ((250, 250), 'RGB')
# Random image size from Delphinium 'Percival' directory is: ((250, 250), 'RGB')
# Random image size from Common Milkweed (Asclepias syriaca) directory is: ((250, 250), 'RGB')
# Random image size from Blazing Star (Liatris spicata) directory is: ((250, 250), 'RGB')
# Random image size from Fancy-leaf Caladium (Caladium Tapestry╬ô├ñ├│) directory is: ((250, 250), 'RGB')
# Random image size from Peony (Paeonia lactiflora 'Do Tell') directory is: ((250, 250), 'RGB')
# Random image size from Elephant's Trunk (Pachypodium namaquanum) directory is: ((250, 250), 'RGB')
# Random image size from Rose (Rosa 'Lavender Crush') directory is: ((250, 250), 'RGB')
# Random image size from Lemon Tree (Citrus x limon 'Eureka') directory is: ((250, 250), 'RGB')
# Random image size from Rose (Rosa 'Sexy Rexy') directory is: ((250, 250), 'RGB')
# Random image size from Wild Thyme (Thymus serpyllum 'Pink Chintz') directory is: ((250, 250), 'RGB')
# Random image size from Columbine (Aquilegia Kirigami╬ô├ñ├│ Rose & Pink) directory is: ((250, 250), 'RGB')
# Random image size from Columbines (Aquilegia) directory is: ((250, 250), 'RGB')
# Random image size from Penstemon Riding Hood Red directory is: ((250, 250), 'RGB')
# Random image size from Lettuce (Lactuca sativa 'Parris Island') directory is: ((250, 250), 'RGB')
# Random image size from Dwarf Peach (Prunus persica 'Bonanza') directory is: ((250, 250), 'RGB')
# Random image size from Rape (Brassica napus subsp. napus) directory is: ((250, 250), 'RGB')
# Random image size from Spearmint (Mentha spicata) directory is: ((250, 250), 'RGB')
# Random image size from Bitter Aloe (Aloe ferox) directory is: ((250, 250), 'RGB')
# Random image size from Large Speedwell (Veronica teucrium 'Crater Lake Blue') directory is: ((250, 250), 'RGB')
# Random image size from Arilbred Iris (Iris 'Stolon Ginger') directory is: ((250, 250), 'RGB')
# Random image size from Tomatoes (Solanum lycopersicum) directory is: ((250, 250), 'RGB')
# Random image size from Dwarf Coneflower (Echinacea KismetΓö¼┬½ Red) directory is: ((250, 250), 'RGB')
# Random image size from Smooth Hydrangea (Hydrangea arborescens 'Annabelle') directory is: ((250, 250), 'RGB')
# Random image size from Chives (Allium schoenoprasum) directory is: ((250, 250), 'RGB')
# Random image size from European Cranberry Viburnum (Viburnum opulus) directory is: ((250, 250), 'RGB')
# Random image size from Delphiniums (Delphinium) directory is: ((250, 250), 'RGB')
# Random image size from Plumeria 'Queen Amber' directory is: ((250, 250), 'RGB')
# Random image size from Garden Phlox (Phlox x arendsii 'Miss Mary') directory is: ((250, 250), 'RGB')
# Random image size from Mock Orange (Philadelphus 'Snow Dwarf') directory is: ((250, 250), 'RGB')
# Random image size from Cilantro (Coriandrum sativum 'Confetti') directory is: ((250, 250), 'RGB')
# Random image size from Curly Parsley (Petroselinum crispum var. crispum) directory is: ((250, 250), 'RGB')
# Random image size from Tall Bearded Iris (Iris 'Blue Me Away') directory is: ((250, 250), 'RGB')
# Random image size from Nepeta (Nepeta subsessilis) directory is: ((250, 250), 'RGB')
# Random image size from Creeping Speedwell (Veronica teucrium) directory is: ((250, 250), 'RGB')
# Random image size from Apple (Malus pumila 'Braeburn') directory is: ((250, 250), 'RGB')
# Random image size from Tulip (Tulipa 'Brown Sugar') directory is: ((250, 250), 'RGB')
# Random image size from Rose (Rosa 'Angel Face') directory is: ((250, 250), 'RGB')
# Random image size from Hosta 'Tom Schmid' directory is: ((250, 250), 'RGB')
# Random image size from Crabapple (Malus 'Prairie Fire') directory is: ((250, 250), 'RGB')
# Random image size from Parsleys (Petroselinum crispum) directory is: ((250, 250), 'RGB')
# Random image size from Winter Radish (Raphanus sativus 'China Rose') directory is: ((250, 250), 'RGB')
# Random image size from Rose of Sharon (Hibiscus syriacus Blue SatinΓö¼┬½) directory is: ((250, 250), 'RGB')
# Random image size from Spiraeas (Spiraea) directory is: ((250, 250), 'RGB')
# Random image size from Purple Marjoram (Origanum laevigatum 'Hopley's') directory is: ((250, 250), 'RGB')
# Random image size from Yarrow (Achillea millefolium 'Sonoma Coast') directory is: ((250, 250), 'RGB')
# Random image size from Butterfly Bush (Buddleja davidii 'Asian Moon') directory is: ((250, 250), 'RGB')
# Random image size from Celery (Apium graveolens var. dulce 'Tall Utah') directory is: ((250, 250), 'RGB')
# Random image size from Gladiola (Gladiolus) directory is: ((250, 250), 'RGB')
# Random image size from Lamb's Ears (Stachys) directory is: ((250, 250), 'RGB')
# Random image size from Eastern Dogwood (Cornus florida var. florida 'Rubra') directory is: ((250, 250), 'RGB')
# Random image size from Rocky Mountain Columbine (Aquilegia coerulea) directory is: ((250, 250), 'RGB')
# Random image size from Hardy Hibiscus (Hibiscus moscheutos 'Kopper King') directory is: ((250, 250), 'RGB')
# Random image size from Confederate Rose (Hibiscus mutabilis) directory is: ((250, 250), 'RGB')
# Random image size from Dills (Anethum graveolens) directory is: ((250, 250), 'RGB')
# Random image size from Hosta 'Blue Angel' directory is: ((250, 250), 'RGB')
# Random image size from Tall Bearded Iris (Iris 'Merchant Marine') directory is: ((250, 250), 'RGB')
# Random image size from Russian Sages (Perovskia) directory is: ((250, 250), 'RGB')
# Random image size from Soap Aloe (Aloe maculata) directory is: ((250, 250), 'RGB')
# Random image size from Tasteless Stonecrop (Sedum sexangulare) directory is: ((250, 250), 'RGB')
# Random image size from Faassen's Catmint (Nepeta x faassenii 'Six Hills Giant') directory is: ((250, 250), 'RGB')
# Random image size from Panicle Hydrangea (Hydrangea paniculata First EditionsΓö¼┬½ Vanilla Strawberry╬ô├ñ├│) directory is: ((250, 250), 'RGB')
# Random image size from Blanket Flower (Gaillardia 'Arizona Sun') directory is: ((250, 250), 'RGB')
# Random image size from Foxgloves (Digitalis) directory is: ((250, 250), 'RGB')
# Random image size from Baby's Breath (Gypsophila elegans 'Kermesina') directory is: ((250, 250), 'RGB')
# Random image size from Baby's Breath (Gypsophila elegans 'Covent Garden') directory is: ((250, 250), 'RGB')
# Random image size from Cos Lettuce (Lactuca sativa 'Little Gem') directory is: ((250, 250), 'RGB')
# Random image size from Bush Bean (Phaseolus vulgaris 'Royal Burgundy') directory is: ((250, 250), 'RGB')
# Random image size from Bellflowers (Campanula) directory is: ((250, 250), 'RGB')
# Random image size from Plumeria (Plumeria rubra 'Naples Sixteen') directory is: ((250, 250), 'RGB')
# Random image size from Wild Asparagus (Asparagus officinalis 'Mary Washington') directory is: ((250, 250), 'RGB')
# Random image size from Plumeria (Plumeria rubra 'Sophie') directory is: ((250, 250), 'RGB')
# Random image size from Aster (Aster x frikartii Wonder of Stafa) directory is: ((250, 250), 'RGB')
# Random image size from Hybrid Gladiola (Gladiolus 'Boone') directory is: ((250, 250), 'RGB')
# Random image size from Lilac (Syringa x hyacinthiflora 'Sweetheart') directory is: ((250, 250), 'RGB')
# Random image size from Lettuce (Lactuca sativa 'Rouge d'Hiver') directory is: ((250, 250), 'RGB')
# Random image size from Gladiolus 'Fiesta' directory is: ((250, 250), 'RGB')
# Random image size from Creeping Phlox (Phlox subulata) directory is: ((250, 250), 'RGB')
# Random image size from Hosta 'White Feather' directory is: ((250, 250), 'RGB')
# Random image size from Heavenly Bamboos (Nandina domestica) directory is: ((250, 250), 'RGB')
# Random image size from Onion (Allium cepa 'Red Hunter') directory is: ((250, 250), 'RGB')
# Random image size from Lilac (Syringa vulgaris 'Sensation') directory is: ((250, 250), 'RGB')
# Random image size from Beet (Beta vulgaris 'Moneta') directory is: ((250, 250), 'RGB')
# Random image size from Delphinium 'Diamonds Blue' directory is: ((250, 250), 'RGB')
# Random image size from Lily (Lilium 'Fusion') directory is: ((250, 250), 'RGB')
# Random image size from Flowering Kale (Brassica oleracea 'Kamome White') directory is: ((250, 250), 'RGB')
# Random image size from Purple Cherry Plum (Prunus cerasifera 'Hollywood') directory is: ((250, 250), 'RGB')
# Random image size from Gardenia (Gardenia jasminoides 'August Beauty') directory is: ((250, 250), 'RGB')
# Random image size from Daylily (Hemerocallis 'Quoting Hemingway') directory is: ((250, 250), 'RGB')
# Random image size from Mountain Aloe (Aloe broomii) directory is: ((250, 250), 'RGB')
# Random image size from Strawberry (Fragaria x ananassa 'Chandler') directory is: ((250, 250), 'RGB')
# Random image size from Arborvitaes (Thuja) directory is: ((250, 250), 'RGB')
# Random image size from Chinese Wisteria (Wisteria sinensis) directory is: ((250, 250), 'RGB')
# Random image size from Butterfly Bush (Buddleja Humdinger╬ô├ñ├│ Magenta Munchkin) directory is: ((250, 250), 'RGB')
# Random image size from Pear (Pyrus communis 'Early Seckel') directory is: ((250, 250), 'RGB')
# Random image size from Flint Corn (Zea mays subsp. mays 'Indian Ornamental') directory is: ((250, 250), 'RGB')
# Random image size from Okra (Abelmoschus esculentus 'Jing Orange') directory is: ((250, 250), 'RGB')
# Random image size from Italian Parsley (Petroselinum crispum 'Italian Flat Leaf') directory is: ((250, 250), 'RGB')
# Random image size from Eastern Ninebark (Physocarpus opulifolius 'Luteus') directory is: ((250, 250), 'RGB')
# Random image size from Cannas (Canna) directory is: ((250, 250), 'RGB')
# Random image size from Crepe Myrtle (Lagerstroemia 'Zuni') directory is: ((250, 250), 'RGB')
# Random image size from Rhododendron 'Inga' directory is: ((250, 250), 'RGB')
# Random image size from Judd Viburnum (Viburnum carlesii var. bitchiuense) directory is: ((250, 250), 'RGB')
# Random image size from Hot Pepper (Capsicum annuum 'Super Chili') directory is: ((250, 250), 'RGB')
# Random image size from Thornless Blackberry (Rubus 'Navaho') directory is: ((250, 250), 'RGB')
# Random image size from Garden Phlox (Phlox paniculata 'Blue Paradise') directory is: ((250, 250), 'RGB')
# Random image size from Speedwell (Veronica peduncularis 'Georgia Blue') directory is: ((250, 250), 'RGB')
# Random image size from Wild Indigo (Baptisia 'Lemon Meringue') directory is: ((250, 250), 'RGB')
# Random image size from Lily Flowering Tulip (Tulipa 'Claudia') directory is: ((250, 250), 'RGB')
# Random image size from New England Aster (Symphyotrichum novae-angliae) directory is: ((250, 250), 'RGB')
# Random image size from Plums (Prunus umbellata) directory is: ((250, 250), 'RGB')
# Random image size from Rose of Sharon (Hibiscus syriacus Chateau╬ô├ñ├│ de Chantilly) directory is: ((250, 250), 'RGB')
# Random image size from Shasta Daisy (Leucanthemum x superbum 'Aglaya') directory is: ((250, 250), 'RGB')
# Random image size from Hybrid Gladiola (Gladiolus x gandavensis 'Priscilla') directory is: ((250, 250), 'RGB')
# Random image size from Astilbe 'Rheinland' directory is: ((250, 250), 'RGB')
# Random image size from Echeveria 'Irish Mint' directory is: ((250, 250), 'RGB')
# Random image size from Turnip (Brassica rapa subsp. rapa 'White Egg') directory is: ((250, 250), 'RGB')
# Random image size from Potato (Solanum tuberosum 'Kennebec') directory is: ((250, 250), 'RGB')
# Random image size from Shasta Daisy (Leucanthemum x superbum Sweet Daisy╬ô├ñ├│ Christine) directory is: ((250, 250), 'RGB')
# Random image size from Tomato (Solanum lycopersicum 'Dark Galaxy') directory is: ((250, 250), 'RGB')
# Random image size from Dwarf Chinese Astilbe (Astilbe rubra 'Pumila') directory is: ((250, 250), 'RGB')
# Random image size from Japanese Wisteria (Wisteria floribunda 'Issai Perfect') directory is: ((250, 250), 'RGB')
# Random image size from Sierra Canelo Pincushion Cactus (Mammillaria standleyi) directory is: ((250, 250), 'RGB')
# Random image size from Spinach (Spinacia oleracea 'Seaside') directory is: ((250, 250), 'RGB')
# Random image size from Delphinium (Delphinium elatum New Millennium╬ô├ñ├│ Royal Aspirations) directory is: ((250, 250), 'RGB')
# Random image size from Eggplant (Solanum melongena 'Annina') directory is: ((250, 250), 'RGB')
# Random image size from Western Red Cedar (Thuja plicata) directory is: ((250, 250), 'RGB')
# Random image size from Coconino County Desert Beardtongue (Penstemon pseudospectabilis 'Coconino County') directory is: ((250, 250), 'RGB')
# Random image size from Crepe Myrtle (Lagerstroemia 'Natchez') directory is: ((250, 250), 'RGB')
# Random image size from Coneflower (Echinacea Double Scoop╬ô├ñ├│ Orangeberry) directory is: ((250, 250), 'RGB')
# Random image size from Roses of Sharon (Hibiscus syriacus) directory is: ((250, 250), 'RGB')
# Random image size from Hibiscus directory is: ((250, 250), 'RGB')
# Random image size from Drummond's Hedgenettle (Stachys drummondii) directory is: ((250, 250), 'RGB')
# Random image size from Leek (Allium ampeloprasum 'Large American Flag') directory is: ((250, 250), 'RGB')
# Random image size from Apple (Malus pumila 'Sweet Bough') directory is: ((250, 250), 'RGB')
# Random image size from Melon (Cucumis melo 'Tigger') directory is: ((250, 250), 'RGB')
# Random image size from Pineberry (Fragaria x ananassa 'White Carolina') directory is: ((250, 250), 'RGB')
# Random image size from English Pea (Pisum sativum 'Alaska') directory is: ((250, 250), 'RGB')
# Random image size from English Pea (Pisum sativum 'Penelope') directory is: ((250, 250), 'RGB')
# Random image size from Tall Phlox (Phlox paniculata) directory is: ((250, 250), 'RGB')
# Random image size from Double Daffodil (Narcissus 'Ice King') directory is: ((250, 250), 'RGB')
# Random image size from Spotted Dead Nettle (Lamium maculatum 'Pink Pewter') directory is: ((250, 250), 'RGB')
# Random image size from Fuchsia Flowering Currant (Ribes speciosum) directory is: ((250, 250), 'RGB')
# Random image size from Rose of Sharon (Hibiscus Pollypetite╬ô├ñ├│) directory is: ((250, 250), 'RGB')
# Random image size from Shasta Daisy (Leucanthemum x superbum 'Snowcap') directory is: ((250, 250), 'RGB')
# Random image size from Dahlia 'Hapet Champagne' directory is: ((250, 250), 'RGB')
# Random image size from Astilbe 'Straussenfeder' directory is: ((250, 250), 'RGB')
# Random image size from Coral Honeysuckle (Lonicera sempervirens) directory is: ((250, 250), 'RGB')
# Random image size from Flat-Flowered Aloe (Aloe marlothii) directory is: ((250, 250), 'RGB')
# Random image size from Morning Glory (Ipomoea hederifolia 'Aurantia') directory is: ((250, 250), 'RGB')
# Random image size from Tomato (Solanum lycopersicum 'Park's Whopper') directory is: ((250, 250), 'RGB')
# Random image size from Dark Opal Basil (Ocimum basilicum 'Purpurascens') directory is: ((250, 250), 'RGB')
# Random image size from Hortulan Plum (Prunus hortulana) directory is: ((250, 250), 'RGB')
# Random image size from Lily (Lilium 'Corsage') directory is: ((250, 250), 'RGB')
# Random image size from Hen and Chicks (Sempervivum 'Lynn's Rose Gold') directory is: ((250, 250), 'RGB')
# Random image size from Tomato (Solanum lycopersicum 'Pink Delicious') directory is: ((250, 250), 'RGB')
# ...
# Random image size from Sweet Cherry (Prunus avium 'Black Tatarian') directory is: ((250, 250), 'RGB')
# Random image size from Astilbes (Astilbe) directory is: ((250, 250), 'RGB')
# Random image size from Heavenly Bamboo (Nandina domestica 'Moon Bay') directory is: ((250, 250), 'RGB')
# Random image size from Spider Plant (Chlorophytum comosum) directory is: ((250, 250), 'RGB')
# Random image size from Eggplant (Solanum melongena 'Orient Express') directory is: ((250, 250), 'RGB')
# Random image size from Plumerias (Plumeria) directory is: ((250, 250), 'RGB')
# Random image size from Meserve Holly (Ilex 'Casanova') directory is: ((250, 250), 'RGB')
# Random image size from Citron (Citrus medica) directory is: ((250, 250), 'RGB')
# Random image size from Wild Blackberry (Rubus cochinchinensis) directory is: ((250, 250), 'RGB')
# Random image size from Meyer's Lemon (Citrus x limon 'Improved Meyer') directory is: ((250, 250), 'RGB')
# Random image size from Kale (Brassica oleracea var. viridis 'Redbor') directory is: ((250, 250), 'RGB')
# Random image size from Tarragons (Artemisia dracunculus) directory is: ((250, 250), 'RGB')
# Random image size from Radish (Raphanus sativus 'Amethyst') directory is: ((250, 250), 'RGB')
# Random image size from Lemon (Citrus x limon) directory is: ((250, 250), 'RGB')
# Random image size from Squid Agave (Agave bracteosa) directory is: ((250, 250), 'RGB')
# Random image size from Intersectional Peony (Paeonia 'All That Jazz') directory is: ((250, 250), 'RGB')
# Random image size from Cucumber (Cucumis sativus 'Double Yield') directory is: ((250, 250), 'RGB')
# Random image size from Tickseed (Coreopsis Satin & Lace╬ô├ñ├│ Red Chiffon) directory is: ((250, 250), 'RGB')
# Random image size from Nectarine (Prunus persica 'Early Rivers') directory is: ((250, 250), 'RGB')
# Random image size from Asters (Aster) directory is: ((250, 250), 'RGB')
# Random image size from Hen and chicks (Sempervivum 'Dea') directory is: ((250, 250), 'RGB')
# Random image size from Japanese Morning Glory (Ipomoea nil 'Seiryu') directory is: ((250, 250), 'RGB')
# Random image size from Red Flowering Currant (Ribes sanguineum 'Brocklebankii') directory is: ((250, 250), 'RGB')
# Random image size from Winterberry Holly (Ilex verticillata 'Winter Red') directory is: ((250, 250), 'RGB')
# Random image size from Celeriac (Apium graveolens var. rapaceum 'Prinz') directory is: ((250, 250), 'RGB')
# Random image size from Shirley Poppy (Papaver rhoeas 'Amazing Grey') directory is: ((250, 250), 'RGB')
# Random image size from Poppy (Papaver 'Sugar Plum') directory is: ((250, 250), 'RGB')
# Random image size from Siempreviva (Dudleya attenuata) directory is: ((250, 250), 'RGB')
# Random image size from Red Currant (Ribes rubrum 'Red Lake') directory is: ((250, 250), 'RGB')
# Random image size from Bigleaf Hydrangea (Hydrangea macrophylla) directory is: ((250, 250), 'RGB')
# Random image size from Giant Chalk Dudleya (Dudleya brittonii) directory is: ((250, 250), 'RGB')
# Random image size from Okra (Abelmoschus esculentus 'Burmese') directory is: ((250, 250), 'RGB')
# Random image size from Echeveria 'Perle von Nurnberg' directory is: ((250, 250), 'RGB')
# Random image size from Mexican Plum (Prunus mexicana) directory is: ((250, 250), 'RGB')
# Random image size from Potatoes (Solanum tuberosum) directory is: ((250, 250), 'RGB')
# Random image size from Eggplant (Solanum melongena 'Violet King') directory is: ((250, 250), 'RGB')
# Random image size from Dudleyas (Dudleya) directory is: ((250, 250), 'RGB')
# Random image size from California Fishhook Cactus (Mammillaria dioica) directory is: ((250, 250), 'RGB')
# Random image size from Caladium bicolor 'Fiesta' directory is: ((250, 250), 'RGB')
# Random image size from Crinums (Crinum) directory is: ((250, 250), 'RGB')
# Random image size from Petunia PotuniaΓö¼┬½ Purple Halo directory is: ((250, 250), 'RGB')
# Random image size from Flower of an Hour (Hibiscus trionum) directory is: ((250, 250), 'RGB')
# Random image size from Okra (Abelmoschus esculentus 'Red Burgundy') directory is: ((250, 250), 'RGB')
# Random image size from Dwarf Mouse-ear Tickseed (Coreopsis auriculata 'Nana') directory is: ((250, 250), 'RGB')
# Random image size from Double Reeves Spirea (Spiraea cantoniensis 'Lanceata') directory is: ((250, 250), 'RGB')
# Random image size from Waterlily Tulip (Tulipa kaufmanniana 'Scarlet Baby') directory is: ((250, 250), 'RGB')
# Random image size from Georgia Sweet Vidalia Onion (Allium cepa 'Yellow Granex') directory is: ((250, 250), 'RGB')
# Random image size from Woolly Thyme (Thymus praecox subsp. polytrichus) directory is: ((250, 250), 'RGB')
# Random image size from Peppers (Capsicum) directory is: ((250, 250), 'RGB')
# Random image size from Columbine (Aquilegia coerulea Origami╬ô├ñ├│ Blue & White) directory is: ((250, 250), 'RGB')
# Random image size from Coneflower (Echinacea 'Virgin') directory is: ((250, 250), 'RGB')
# Random image size from Milk and Wine Lily (Crinum fimbriatulum) directory is: ((250, 250), 'RGB')
# Random image size from Waterlily Tulip (Tulipa kaufmanniana 'Corona') directory is: ((250, 250), 'RGB')
# Random image size from Sand Pink (Dianthus arenarius) directory is: ((250, 250), 'RGB')
# Random image size from Lily (Lilium auratum) directory is: ((250, 250), 'RGB')
# Random image size from Rhododendron 'Queen of England' directory is: ((250, 250), 'RGB')
# Random image size from Potato (Solanum tuberosum 'Baltic Rose') directory is: ((250, 250), 'RGB')
# Random image size from Tall Bearded Iris (Iris 'Radiant Garnet') directory is: ((250, 250), 'RGB')
# Random image size from Hummingbird Sage (Salvia coccinea 'Coral Nymph') directory is: ((250, 250), 'RGB')
# Random image size from Hostas (Hosta) directory is: ((250, 250), 'RGB')
# Random image size from Artichokes (Cynara scolymus) directory is: ((250, 250), 'RGB')
# Random image size from Onion (Allium cepa 'Walla Walla Sweet') directory is: ((250, 250), 'RGB')
# Random image size from Asparagus officinalis 'Mondeo' directory is: ((250, 250), 'RGB')
# Random image size from Yarrows (Achillea) directory is: ((250, 250), 'RGB')
# Random image size from French Lilac (Syringa vulgaris 'Miss Ellen Willmott') directory is: ((250, 250), 'RGB')
# Random image size from Egyptian Walking Onion (Allium x proliferum) directory is: ((250, 250), 'RGB')
# Random image size from Conchilinque (Mammillaria pectinifera) directory is: ((250, 250), 'RGB')
# Random image size from Astilbe 'Peach Blossom' directory is: ((250, 250), 'RGB')
# Random image size from Yaupon Holly (Ilex vomitoria) directory is: ((250, 250), 'RGB')
# Random image size from Speedwell (Veronica oltensis) directory is: ((250, 250), 'RGB')
# Random image size from Basils (Ocimum) directory is: ((250, 250), 'RGB')
# Random image size from Grapes (Vitis) directory is: ((250, 250), 'RGB')
# Random image size from Potato (Solanum tuberosum 'Bojar') directory is: ((250, 250), 'RGB')
# Random image size from Blanket Flower (Gaillardia pulchella) directory is: ((250, 250), 'RGB')
# Random image size from Turnips (Brassica rapa subsp. rapa) directory is: ((250, 250), 'RGB')
# Random image size from Tickseed (Coreopsis Cruizin'╬ô├ñ├│ Main Street) directory is: ((250, 250), 'RGB')
# Random image size from Pumpkin (Cucurbita moschata 'Musquee de Provence') directory is: ((250, 250), 'RGB')
# Random image size from Peach (Prunus persica 'Elberta') directory is: ((250, 250), 'RGB')
# Random image size from Gladiolus 'Atom' directory is: ((250, 250), 'RGB')
# Random image size from Okra (Abelmoschus esculentus) directory is: ((250, 250), 'RGB')
# Random image size from Sweet Basil (Ocimum basilicum) directory is: ((250, 250), 'RGB')
# Random image size from Spinach (Spinacia oleracea 'Alexandria') directory is: ((250, 250), 'RGB')
# Random image size from Rhubarb (Rheum rhabarbarum 'Victoria') directory is: ((250, 250), 'RGB')
# Random image size from Apricots (Prunus armeniaca) directory is: ((250, 250), 'RGB')
# Random image size from Ornamental Pepper (Capsicum annuum 'Chilly Chili') directory is: ((250, 250), 'RGB')
# Random image size from Pachypodium (Pachypodium sofiense) directory is: ((250, 250), 'RGB')
# Random image size from Cantaloupe (Cucumis melo 'Orange Silverwave') directory is: ((250, 250), 'RGB')
# Random image size from Salvia (Salvia coerulea 'Sapphire Blue') directory is: ((250, 250), 'RGB')
# Random image size from Aeonium (Aeonium davidbramwellii 'Sunburst') directory is: ((250, 250), 'RGB')
# Random image size from Spinach (Spinacia oleracea 'Reflect') directory is: ((250, 250), 'RGB')
# Random image size from Morning Glory (Ipomoea purpurea 'Feringa') directory is: ((250, 250), 'RGB')
# Random image size from Aromatic Aster (Symphyotrichum oblongifolium 'October Skies') directory is: ((250, 250), 'RGB')
# Random image size from Purple Coneflower (Echinacea purpurea 'Rubinstern') directory is: ((250, 250), 'RGB')
# Random image size from Chalk Rose (Dudleya candida) directory is: ((250, 250), 'RGB')
# Random image size from Radish (Raphanus sativus 'German Giant') directory is: ((250, 250), 'RGB')
# Random image size from Turnip (Brassica rapa subsp. rapa 'Gold Ball') directory is: ((250, 250), 'RGB')
# Random image size from Bright Green Dudleya (Dudleya virens) directory is: ((250, 250), 'RGB')
# Random image size from Coneflower (Echinacea SombreroΓö¼┬½ Lemon Yellow Improved) directory is: ((250, 250), 'RGB')
# Random image size from Swiss Chard (Beta vulgaris subsp. cicla 'Bright Lights') directory is: ((250, 250), 'RGB')
# Random image size from Dwarf Burford Holly (Ilex cornuta 'Burfordii Nana') directory is: ((250, 250), 'RGB')
# Random image size from Bean (Phaseolus vulgaris 'Cherokee Trail of Tears') directory is: ((250, 250), 'RGB')
# Random image size from Eggplant (Solanum melongena 'Black Beauty') directory is: ((250, 250), 'RGB')
# Random image size from Apple Mint (Mentha suaveolens) directory is: ((250, 250), 'RGB')
# Random image size from Carrot (Daucus carota subsp. sativus 'Black Nebula') directory is: ((250, 250), 'RGB')
# Random image size from Chinese Lanterns (Hibiscus schizopetalus) directory is: ((250, 250), 'RGB')
# Random image size from American Wisteria (Wisteria frutescens 'Blue Moon') directory is: ((250, 250), 'RGB')
# Random image size from Western Red Cedar (Thuja plicata Forever GoldyΓö¼┬½) directory is: ((250, 250), 'RGB')
# Random image size from Radishes (Raphanus sativus) directory is: ((250, 250), 'RGB')
# Random image size from Beet (Beta vulgaris 'Bull's Blood') directory is: ((250, 250), 'RGB')
# Random image size from Petunia Midnight Gold directory is: ((250, 250), 'RGB')
# Random image size from Wild Asparagus (Asparagus officinalis 'Jersey Knight') directory is: ((250, 250), 'RGB')
# Random image size from Yarrow (Achillea millefolium 'Paprika') directory is: ((250, 250), 'RGB')
# Random image size from Echeveria (Echeveria setosa var. minor) directory is: ((250, 250), 'RGB')
# Random image size from Snap Bean (String (Phaseolus vulgaris 'Wren's Egg') directory is: ((250, 250), 'RGB')
# Random image size from Slow Bolt Cilantro (Coriandrum sativum 'Santo') directory is: ((250, 250), 'RGB')
# Random image size from Snap Bean (String (Phaseolus vulgaris 'Blue Lake Bush #274') directory is: ((250, 250), 'RGB')
# Random image size from Trumpet Daffodil (Narcissus 'Marieke') directory is: ((250, 250), 'RGB')
# Random image size from Common Sage (Salvia officinalis 'Tricolor') directory is: ((250, 250), 'RGB')
# Random image size from Tulip (Tulipa 'Rasta Parrot') directory is: ((250, 250), 'RGB')
# Random image size from Canna 'Annjee' directory is: ((250, 250), 'RGB')
# Random image size from Hosta 'Whirlwind' directory is: ((250, 250), 'RGB')
# Random image size from Texas Nipple Cactus (Mammillaria prolifera subsp. texana) directory is: ((250, 250), 'RGB')
# Random image size from Dahlia 'Formby Sunrise' directory is: ((250, 250), 'RGB')
# Random image size from Dahlia 'Thomas A. Edison' directory is: ((250, 250), 'RGB')
# Random image size from Garlic (Allium sativum 'Early Red Italian') directory is: ((250, 250), 'RGB')
# Random image size from Chinese Pear (Pyrus pyrifolia 'Shinseiki') directory is: ((250, 250), 'RGB')
# Random image size from Butterwort (Pinguicula gigantea) directory is: ((250, 250), 'RGB')
# Random image size from Shirley Poppy (Papaver rhoeas 'Double Mixed') directory is: ((250, 250), 'RGB')
# Random image size from Dutch Hyacinth (Hyacinthus orientalis 'Hollyhock') directory is: ((250, 250), 'RGB')
# Random image size from Silver Margined Holly (Ilex aquifolium 'Argentea Marginata') directory is: ((250, 250), 'RGB')
# Random image size from Bee Balm (Monarda 'Trinity Purple') directory is: ((250, 250), 'RGB')
# Random image size from Loose-leaf Lettuce (Lactuca sativa 'Salad Bowl') directory is: ((250, 250), 'RGB')
# Random image size from Bee Balm (Monarda 'Purple Rooster') directory is: ((250, 250), 'RGB')
# Random image size from Azalea (Rhododendron 'Irene Koster') directory is: ((250, 250), 'RGB')
# Random image size from Bridalwreath Spiraea (Spiraea prunifolia) directory is: ((250, 250), 'RGB')
# Random image size from Triple Sweet Corn (Zea mays 'Alto') directory is: ((250, 250), 'RGB')
# Random image size from Persian Catmint (Nepeta racemosa 'Little Titch') directory is: ((250, 250), 'RGB')
# Random image size from Bellflower (Campanula x haylodgensis 'Blue Wonder') directory is: ((250, 250), 'RGB')
# Random image size from Tall Bearded Iris (Iris 'Lemon Cloud') directory is: ((250, 250), 'RGB')
# Random image size from Tomato (Solanum lycopersicum 'Goldman's Italian-American') directory is: ((250, 250), 'RGB')
# Random image size from Genovese Basil (Ocimum basilicum 'Dolce Fresca') directory is: ((250, 250), 'RGB')
# Random image size from Sierra Leone Lily (Chlorophytum 'Fireflash') directory is: ((250, 250), 'RGB')
# Random image size from Aeonium (Aeonium nobile) directory is: ((250, 250), 'RGB')
# Random image size from Common Jujube (Ziziphus jujuba 'Li') directory is: ((250, 250), 'RGB')
# Random image size from Celeriac (Apium graveolens var. rapaceum 'Prague Giant') directory is: ((250, 250), 'RGB')
# Random image size from Lily (Lilium 'Viva La Vida') directory is: ((250, 250), 'RGB')
# Random image size from Hen and Chicks (Sempervivum 'Space Dog') directory is: ((250, 250), 'RGB')
# Random image size from Madagascar Palm (Pachypodium geayi) directory is: ((250, 250), 'RGB')
# Random image size from Gooseberry (Ribes uva-crispa) directory is: ((250, 250), 'RGB')
# Random image size from Rhododendron 'Mother of Pearl' directory is: ((250, 250), 'RGB')
# Random image size from Eggplant (Solanum melongena 'Orlando') directory is: ((250, 250), 'RGB')
# Random image size from Pacific Coast Iris (Iris 'Caught in the Wind') directory is: ((250, 250), 'RGB')
# Random image size from Hot Pepper (Capsicum annuum 'Petit Marseillais') directory is: ((250, 250), 'RGB')
# Random image size from Thimbleberry (Rubus nutkanus) directory is: ((250, 250), 'RGB')
# Random image size from Chocolate Mint (Mentha x piperita 'Chocolate') directory is: ((250, 250), 'RGB')
# Random image size from Butterfly Milkweed (Asclepias tuberosa) directory is: ((250, 250), 'RGB')
# Random image size from Plumeria (Plumeria filifolia) directory is: ((250, 250), 'RGB')
# Random image size from Daylily (Hemerocallis 'Dearest Mahogany') directory is: ((250, 250), 'RGB')
# Random image size from Tomato (Solanum lycopersicum 'Sungold') directory is: ((250, 250), 'RGB')
# Random image size from Colorado Narrowleaf Beardtongue (Penstemon linarioides) directory is: ((250, 250), 'RGB')
# Random image size from Plumeria (Plumeria rubra 'Mellow Yellow') directory is: ((250, 250), 'RGB')
# Random image size from Phlox drummondii 'Sugar Stars' directory is: ((250, 250), 'RGB')
# Random image size from Blue Wild Indigo (Baptisia australis) directory is: ((250, 250), 'RGB')
# Random image size from Holly (Ilex 'Nellie R. Stevens') directory is: ((250, 250), 'RGB')
# Random image size from Winterberry Holly (Ilex verticillata 'Chrysocarpa') directory is: ((250, 250), 'RGB')
# Random image size from Trumpet Narcissus (Narcissus 'Bravoure') directory is: ((250, 250), 'RGB')

# %%
from shutil import copyfile

def create_train_validation(data_path, training_path, validation_path, split_s):
    """
    Split the data into train and validation datasets

    Args:
      -data_path (string): directory path containing images
      -training_path (string): directory path to be used for training
      -validation_path (string): directory path to be used for validation
      -split_s (float): portion of the dataset to be used for training

    Returns:
      None
    """

    dirs = os.listdir(data_path)
    print("Data directories:")
    for img in dirs:
        print(f'-{img}')
    
    try:
        os.makedirs(training_path)
    except FileExistsError:
        print('\nTraining directory exists in this path')

    try:
        os.makedirs(validation_path)
    except FileExistsError:
        print('Validation directory exists in this path')

    direcotries_sizes = data_counter(data_path)
    
    for dir in dirs:
        train_name = os.path.join(training_path, dir)
        validation_name = os.path.join(validation_path, dir)
        os.makedirs(train_name)
        os.makedirs(validation_name)
        split = int(direcotries_sizes[dir] * split_s)
        
        curr_dir = os.path.join(data_path, dir)
        dir_shuffled = sample(os.listdir(curr_dir), len(os.listdir(curr_dir)))

        for img in dir_shuffled[:split]:
            copyfile(os.path.join(curr_dir, img), os.path.join(train_name, img))
        
        for img in dir_shuffled[split:]:
            copyfile(os.path.join(curr_dir, img), os.path.join(validation_name, img))
    
    # print(f'\nTraining sizes: {data_counter(training_path)}')
    # print(f'\nValidation sizes: {data_counter(validation_path)}')

    return training_path, validation_path

training_path, validation_path = create_train_validation(photos_path, os.path.join(FLOWERS_PATH, 'training/'), os.path.join(FLOWERS_PATH, 'validation/'), .7)
# Out:
# Data directories:
# -Winter Honeysuckle (Lonicera fragrantissima)
# -Carrot (Daucus carota subsp. sativus 'Ultimate Hybrid')
# -Butterwort (Pinguicula moctezumae)
# -Sweet Potato (Ipomoea batatas Sweet Caroline Sweetheart Jet Black╬ô├ñ├│)
# -Smoketrees (Cotinus coggygria)
# -Cantaloupes (Cucumis melo)
# -Garlic (Allium sativum 'Georgian Crystal')
# -Astilbe 'Fanal'
# -Leeks (Allium ampeloprasum)
# -Western Red Cedar (Thuja plicata 'Whipcord')
# -Pumpkin (Cucurbita pepo 'Winter Luxury Pie')
# -Echeveria (Echeveria runyonii)
# -Radish (Raphanus sativus 'Early Scarlet Globe')
# -Purple Basil (Ocimum basilicum 'Purple Delight')
# -Dahlia 'AC Sadie'
# -Onion (Allium cepa 'Red River F1')
# -Strawberries (Fragaria)
# -American Cranberrybush Viburnum (Viburnum opulus var. americanum)
# -Morning Glory (Ipomoea 'Split Second')
# -Morning Glory (Ipomoea nil 'Kikyo Snowflakes')
# -Apricot (Prunus armeniaca 'Gold Kist')
# -Aeonium 'Mardi Gras'
# -Dwarf Caladium (Caladium humboldtii)
# -Chinese Wisteria (Wisteria sinensis 'Prolific')
# -Peach (Prunus persica Flamin' FuryΓö¼┬½ PF-24C)
# -Wild Bergamot (Monarda fistulosa)
# -Biznaga de Otero (Mammillaria oteroi)
# -Russian Sage (Perovskia atriplicifolia)
# -Mock Orange (Philadelphus 'Innocence')
# -Butterhead Lettuce (Lactuca sativa 'Tom Thumb')
# -Chinese Dogwood (Cornus kousa subsp. chinensis 'Milky Way')
# -Hardy Geranium (Geranium sanguineum 'Elke')
# -Lilac (Syringa vulgaris 'Belle de Nancy')
# -Hot Pepper (Capsicum baccatum 'Brazilian Starfish')
# -Winter Squash (Cucurbita maxima 'Buttercup')
# -Cheddar Pink (Dianthus gratianopolitanus BluKiss╬ô├ñ├│)
# -Cucumber (Cucumis sativus 'Artist')
# -Smoke Tree (Cotinus coggygria 'Royal Purple')
# -Loose-leaf Lettuce (Lactuca sativa 'Salad Bowl')
# -Bee Balm (Monarda 'Purple Rooster')
# -Azalea (Rhododendron 'Irene Koster')
# -Bridalwreath Spiraea (Spiraea prunifolia)
# -Triple Sweet Corn (Zea mays 'Alto')
# -Persian Catmint (Nepeta racemosa 'Little Titch')
# -Bellflower (Campanula x haylodgensis 'Blue Wonder')
# -Tall Bearded Iris (Iris 'Lemon Cloud')
# -Tomato (Solanum lycopersicum 'Goldman's Italian-American')
# -Genovese Basil (Ocimum basilicum 'Dolce Fresca')
# -Sierra Leone Lily (Chlorophytum 'Fireflash')
# -Aeonium (Aeonium nobile)
# -Common Jujube (Ziziphus jujuba 'Li')
# -Celeriac (Apium graveolens var. rapaceum 'Prague Giant')
# -Lily (Lilium 'Viva La Vida')
# -Hen and Chicks (Sempervivum 'Space Dog')
# -Madagascar Palm (Pachypodium geayi)
# -Gooseberry (Ribes uva-crispa)
# -Rhododendron 'Mother of Pearl'
# -Eggplant (Solanum melongena 'Orlando')
# -Pacific Coast Iris (Iris 'Caught in the Wind')
# -Hot Pepper (Capsicum annuum 'Petit Marseillais')
# -Thimbleberry (Rubus nutkanus)
# -Chocolate Mint (Mentha x piperita 'Chocolate')
# -Butterfly Milkweed (Asclepias tuberosa)
# -Plumeria (Plumeria filifolia)
# -Daylily (Hemerocallis 'Dearest Mahogany')
# -Tomato (Solanum lycopersicum 'Sungold')
# -Colorado Narrowleaf Beardtongue (Penstemon linarioides)
# -Plumeria (Plumeria rubra 'Mellow Yellow')
# -Phlox drummondii 'Sugar Stars'
# -Blue Wild Indigo (Baptisia australis)
# -Holly (Ilex 'Nellie R. Stevens')
# -Winterberry Holly (Ilex verticillata 'Chrysocarpa')
# -Trumpet Narcissus (Narcissus 'Bravoure')

# %%
from keras.preprocessing.image import ImageDataGenerator

def create_data(train_path, validation_path):
    """
    Create training validation data split

    Args:
      -training_path (string): directory path to be used for training
      -validation_path (string): directory path to be used for validation

    Returns:
      
    """
    training_datagen = ImageDataGenerator(rescale=1/255,
                                        rotation_range=90,
                                        width_shift_range=0.3,
                                        height_shift_range=0.3,
                                        fill_mode='nearest',
                                        horizontal_flip=0.2,
                                        vertical_flip=0.2,
                                        zoom_range=0.3)
    training_data = training_datagen.flow_from_directory(directory=train_path,
                                                        class_mode='categorical',
                                                        target_size=(250, 250),
                                                        batch_size=64,
                                                        shuffle=True)
    
    validation_datagen = ImageDataGenerator(rescale=1/255)

    validation_data = validation_datagen.flow_from_directory(directory=validation_path,
                                                            class_mode='categorical',
                                                            target_size=(250, 250),
                                                            batch_size=64)
    return training_data, validation_data

training_data, validation_data = create_data(training_path, validation_path)
# Out:
# Found 14588 images belonging to 900 classes.
# Found 6845 images belonging to 900 classes.

# %% [markdown]
# ## Model using TensorFlow functional API
#
# We are going to create model from scratch using tf functional API

# %%
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dense, Dropout, Flatten
from keras import Input, Model

inputs = Input(shape=(250, 250 ,3))
x = Conv2D(16, (3, 3), activation='relu')(inputs)
x = Conv2D(16, (3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Conv2D(32, (3, 3), activation='relu')(x)
x = Conv2D(32, (3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(2,2)(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=(2,2))(x)
x = Conv2D(256, (3, 3), activation='relu')(x)
x = Conv2D(256, (3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = Conv2D(512, (3, 3), activation='relu')(x)
x = Conv2D(512, (3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = Flatten()(x)
x = Dense(2048, activation='relu')(x)
x = Dropout(0.6)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.4)(x)
outputs = Dense(900, activation='softmax')(x)

model = Model(inputs, outputs, name='FlowersClassification')
model.summary()
# Out:
# Model: "FlowersClassification"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 250, 250, 3)]     0
#
#  conv2d_114 (Conv2D)         (None, 248, 248, 16)      448
#
#  conv2d_115 (Conv2D)         (None, 246, 246, 16)      2320
#
#  batch_normalization_60 (Bat  (None, 246, 246, 16)     64
#  chNormalization)
#
#  max_pooling2d_43 (MaxPoolin  (None, 123, 123, 16)     0
#  g2D)
#
#  conv2d_116 (Conv2D)         (None, 121, 121, 32)      4640
#
#  conv2d_117 (Conv2D)         (None, 119, 119, 32)      9248
#
#  batch_normalization_61 (Bat  (None, 119, 119, 32)     128
#  chNormalization)
#
#  max_pooling2d_44 (MaxPoolin  (None, 59, 59, 32)       0
#  g2D)
#
#  conv2d_118 (Conv2D)         (None, 57, 57, 64)        18496
#
#  conv2d_119 (Conv2D)         (None, 55, 55, 64)        36928
#
#  batch_normalization_62 (Bat  (None, 55, 55, 64)       256
#  chNormalization)
#
#  max_pooling2d_45 (MaxPoolin  (None, 27, 27, 64)       0
#  g2D)
#
#  conv2d_120 (Conv2D)         (None, 25, 25, 128)       73856
#
#  conv2d_121 (Conv2D)         (None, 23, 23, 128)       147584
#
#  batch_normalization_63 (Bat  (None, 23, 23, 128)      512
#  chNormalization)
#
#  max_pooling2d_46 (MaxPoolin  (None, 11, 11, 128)      0
#  g2D)
#
#  conv2d_122 (Conv2D)         (None, 9, 9, 256)         295168
#
#  conv2d_123 (Conv2D)         (None, 7, 7, 256)         590080
#
#  batch_normalization_64 (Bat  (None, 7, 7, 256)        1024
#  chNormalization)
#
#  conv2d_124 (Conv2D)         (None, 5, 5, 512)         1180160
#
#  conv2d_125 (Conv2D)         (None, 3, 3, 512)         2359808
#
#  batch_normalization_65 (Bat  (None, 3, 3, 512)        2048
#  chNormalization)
#
#  flatten_8 (Flatten)         (None, 4608)              0
#
#  dense_24 (Dense)            (None, 2048)              9439232
#
#  dropout_16 (Dropout)        (None, 2048)              0
#
#  dense_25 (Dense)            (None, 1024)              2098176
#
#  dropout_17 (Dropout)        (None, 1024)              0
#
#  dense_26 (Dense)            (None, 900)               922500
#
# =================================================================
# Total params: 17,182,676
# Trainable params: 17,180,660
# Non-trainable params: 2,016
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
            loss='categorical_crossentropy',
            metrics=['accuracy'])

history = model.fit(training_data,
                    epochs=20,
                    validation_data=validation_data)
# Out:
# Epoch 1/20
# 228/228 [==============================] - 127s 555ms/step - loss: 6.6808 - accuracy: 0.0094 - val_loss: 7.4614 - val_accuracy: 0.0029
# Epoch 2/20
# 228/228 [==============================] - 125s 547ms/step - loss: 6.4104 - accuracy: 0.0162 - val_loss: 6.6427 - val_accuracy: 0.0114
# Epoch 3/20
# 228/228 [==============================] - 124s 543ms/step - loss: 6.2937 - accuracy: 0.0155 - val_loss: 6.3566 - val_accuracy: 0.0153
# Epoch 4/20
# 228/228 [==============================] - 126s 550ms/step - loss: 6.1879 - accuracy: 0.0206 - val_loss: 6.2922 - val_accuracy: 0.0209
# Epoch 5/20
# 228/228 [==============================] - 125s 546ms/step - loss: 6.1178 - accuracy: 0.0225 - val_loss: 6.4836 - val_accuracy: 0.0193
# Epoch 6/20
# 228/228 [==============================] - 125s 546ms/step - loss: 6.1068 - accuracy: 0.0228 - val_loss: 6.0470 - val_accuracy: 0.0235
# Epoch 7/20
# 228/228 [==============================] - 122s 536ms/step - loss: 6.0515 - accuracy: 0.0237 - val_loss: 6.0548 - val_accuracy: 0.0253
# Epoch 8/20
# 228/228 [==============================] - 127s 558ms/step - loss: 6.0094 - accuracy: 0.0244 - val_loss: 6.0184 - val_accuracy: 0.0231
# Epoch 9/20
# 228/228 [==============================] - 128s 561ms/step - loss: 6.0047 - accuracy: 0.0256 - val_loss: 6.1587 - val_accuracy: 0.0250
# Epoch 10/20
# 228/228 [==============================] - 128s 562ms/step - loss: 5.9598 - accuracy: 0.0245 - val_loss: 6.0272 - val_accuracy: 0.0245
# Epoch 11/20
# 228/228 [==============================] - 127s 556ms/step - loss: 5.9123 - accuracy: 0.0265 - val_loss: 6.5925 - val_accuracy: 0.0095
# Epoch 12/20
#  68/228 [=======>......................] - ETA: 1:25 - loss: 5.8592 - accuracy: 0.0287
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/barti/deep/tenorflow-projects/flowers_kagle.ipynb Cell 14' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000013?line=0'>1</a> model.compile(optimizer='adam',
#       <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000013?line=1'>2</a>             loss='categorical_crossentropy',
#       <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000013?line=2'>3</a>             metrics=['accuracy'])
# ----> <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000013?line=4'>5</a> history = model.fit(training_data,
#       <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000013?line=5'>6</a>                     epochs=20,
#       <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000013?line=6'>7</a>                     validation_data=validation_data)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Transfer Learning

# %%
from keras.applications import MobileNetV2

transfer = MobileNetV2(input_shape=(250, 250, 3),
                            include_top=False,
                            weights='imagenet')

transfer.summary()

for layer in transfer.layers:
    layer.trainable = False


last_layer = transfer.get_layer('Conv_1_bn')
print('last layer output shape: ', last_layer.output_shape)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_20 (InputLayer)          [(None, 250, 250, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 125, 125, 32  864         ['input_20[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 125, 125, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 125, 125, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 125, 125, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 125, 125, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 125, 125, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 125, 125, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 125, 125, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
#  block_1_expand (Conv2D)        (None, 125, 125, 96  1536        ['expanded_conv_project_BN[0][0]'
#                                 )                                ]
#
#  block_1_expand_BN (BatchNormal  (None, 125, 125, 96  384        ['block_1_expand[0][0]']
#  ization)                       )
#
#  block_1_expand_relu (ReLU)     (None, 125, 125, 96  0           ['block_1_expand_BN[0][0]']
#                                 )
#
#  block_1_pad (ZeroPadding2D)    (None, 127, 127, 96  0           ['block_1_expand_relu[0][0]']
#                                 )
#
#  block_1_depthwise (DepthwiseCo  (None, 63, 63, 96)  864         ['block_1_pad[0][0]']
#  nv2D)
#
#  block_1_depthwise_BN (BatchNor  (None, 63, 63, 96)  384         ['block_1_depthwise[0][0]']
#  malization)
#
#  block_1_depthwise_relu (ReLU)  (None, 63, 63, 96)   0           ['block_1_depthwise_BN[0][0]']
#
#  block_1_project (Conv2D)       (None, 63, 63, 24)   2304        ['block_1_depthwise_relu[0][0]']
#
#  block_1_project_BN (BatchNorma  (None, 63, 63, 24)  96          ['block_1_project[0][0]']
#  lization)
#
#  block_2_expand (Conv2D)        (None, 63, 63, 144)  3456        ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNormal  (None, 63, 63, 144)  576        ['block_2_expand[0][0]']
#  ization)
#
#  block_2_expand_relu (ReLU)     (None, 63, 63, 144)  0           ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (DepthwiseCo  (None, 63, 63, 144)  1296       ['block_2_expand_relu[0][0]']
#  nv2D)
#
#  block_2_depthwise_BN (BatchNor  (None, 63, 63, 144)  576        ['block_2_depthwise[0][0]']
#  malization)
#
#  block_2_depthwise_relu (ReLU)  (None, 63, 63, 144)  0           ['block_2_depthwise_BN[0][0]']
#
#  block_2_project (Conv2D)       (None, 63, 63, 24)   3456        ['block_2_depthwise_relu[0][0]']
#
#  block_2_project_BN (BatchNorma  (None, 63, 63, 24)  96          ['block_2_project[0][0]']
#  lization)
#
#  block_2_add (Add)              (None, 63, 63, 24)   0           ['block_1_project_BN[0][0]',
#                                                                   'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, 63, 63, 144)  3456        ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNormal  (None, 63, 63, 144)  576        ['block_3_expand[0][0]']
#  ization)
#
#  block_3_expand_relu (ReLU)     (None, 63, 63, 144)  0           ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D)    (None, 65, 65, 144)  0           ['block_3_expand_relu[0][0]']
#
#  block_3_depthwise (DepthwiseCo  (None, 32, 32, 144)  1296       ['block_3_pad[0][0]']
#  nv2D)
#
#  block_3_depthwise_BN (BatchNor  (None, 32, 32, 144)  576        ['block_3_depthwise[0][0]']
#  malization)
#
#  block_3_depthwise_relu (ReLU)  (None, 32, 32, 144)  0           ['block_3_depthwise_BN[0][0]']
#
#  block_3_project (Conv2D)       (None, 32, 32, 32)   4608        ['block_3_depthwise_relu[0][0]']
#
#  block_3_project_BN (BatchNorma  (None, 32, 32, 32)  128         ['block_3_project[0][0]']
#  lization)
#
#  block_4_expand (Conv2D)        (None, 32, 32, 192)  6144        ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNormal  (None, 32, 32, 192)  768        ['block_4_expand[0][0]']
#  ization)
#
#  block_4_expand_relu (ReLU)     (None, 32, 32, 192)  0           ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (DepthwiseCo  (None, 32, 32, 192)  1728       ['block_4_expand_relu[0][0]']
#  nv2D)
#
#  block_4_depthwise_BN (BatchNor  (None, 32, 32, 192)  768        ['block_4_depthwise[0][0]']
#  malization)
#
#  block_4_depthwise_relu (ReLU)  (None, 32, 32, 192)  0           ['block_4_depthwise_BN[0][0]']
#
#  block_4_project (Conv2D)       (None, 32, 32, 32)   6144        ['block_4_depthwise_relu[0][0]']
#
#  block_4_project_BN (BatchNorma  (None, 32, 32, 32)  128         ['block_4_project[0][0]']
#  lization)
#
#  block_4_add (Add)              (None, 32, 32, 32)   0           ['block_3_project_BN[0][0]',
#                                                                   'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, 32, 32, 192)  6144        ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNormal  (None, 32, 32, 192)  768        ['block_5_expand[0][0]']
#  ization)
#
#  block_5_expand_relu (ReLU)     (None, 32, 32, 192)  0           ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (DepthwiseCo  (None, 32, 32, 192)  1728       ['block_5_expand_relu[0][0]']
#  nv2D)
#
#  block_5_depthwise_BN (BatchNor  (None, 32, 32, 192)  768        ['block_5_depthwise[0][0]']
#  malization)
#
#  block_5_depthwise_relu (ReLU)  (None, 32, 32, 192)  0           ['block_5_depthwise_BN[0][0]']
#
#  block_5_project (Conv2D)       (None, 32, 32, 32)   6144        ['block_5_depthwise_relu[0][0]']
#
#  block_5_project_BN (BatchNorma  (None, 32, 32, 32)  128         ['block_5_project[0][0]']
#  lization)
#
#  block_5_add (Add)              (None, 32, 32, 32)   0           ['block_4_add[0][0]',
#                                                                   'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, 32, 32, 192)  6144        ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNormal  (None, 32, 32, 192)  768        ['block_6_expand[0][0]']
#  ization)
#
#  block_6_expand_relu (ReLU)     (None, 32, 32, 192)  0           ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D)    (None, 33, 33, 192)  0           ['block_6_expand_relu[0][0]']
#
#  block_6_depthwise (DepthwiseCo  (None, 16, 16, 192)  1728       ['block_6_pad[0][0]']
#  nv2D)
#
#  block_6_depthwise_BN (BatchNor  (None, 16, 16, 192)  768        ['block_6_depthwise[0][0]']
#  malization)
#
#  block_6_depthwise_relu (ReLU)  (None, 16, 16, 192)  0           ['block_6_depthwise_BN[0][0]']
#
#  block_6_project (Conv2D)       (None, 16, 16, 64)   12288       ['block_6_depthwise_relu[0][0]']
#
#  block_6_project_BN (BatchNorma  (None, 16, 16, 64)  256         ['block_6_project[0][0]']
#  lization)
#
#  block_7_expand (Conv2D)        (None, 16, 16, 384)  24576       ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNormal  (None, 16, 16, 384)  1536       ['block_7_expand[0][0]']
#  ization)
#
#  block_7_expand_relu (ReLU)     (None, 16, 16, 384)  0           ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (DepthwiseCo  (None, 16, 16, 384)  3456       ['block_7_expand_relu[0][0]']
#  nv2D)
#
#  block_7_depthwise_BN (BatchNor  (None, 16, 16, 384)  1536       ['block_7_depthwise[0][0]']
#  malization)
#
#  block_7_depthwise_relu (ReLU)  (None, 16, 16, 384)  0           ['block_7_depthwise_BN[0][0]']
#
#  block_7_project (Conv2D)       (None, 16, 16, 64)   24576       ['block_7_depthwise_relu[0][0]']
#
#  block_7_project_BN (BatchNorma  (None, 16, 16, 64)  256         ['block_7_project[0][0]']
#  lization)
#
#  block_7_add (Add)              (None, 16, 16, 64)   0           ['block_6_project_BN[0][0]',
#                                                                   'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, 16, 16, 384)  24576       ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNormal  (None, 16, 16, 384)  1536       ['block_8_expand[0][0]']
#  ization)
#
#  block_8_expand_relu (ReLU)     (None, 16, 16, 384)  0           ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (DepthwiseCo  (None, 16, 16, 384)  3456       ['block_8_expand_relu[0][0]']
#  nv2D)
#
#  block_8_depthwise_BN (BatchNor  (None, 16, 16, 384)  1536       ['block_8_depthwise[0][0]']
#  malization)
#
#  block_8_depthwise_relu (ReLU)  (None, 16, 16, 384)  0           ['block_8_depthwise_BN[0][0]']
#
#  block_8_project (Conv2D)       (None, 16, 16, 64)   24576       ['block_8_depthwise_relu[0][0]']
#
#  block_8_project_BN (BatchNorma  (None, 16, 16, 64)  256         ['block_8_project[0][0]']
#  lization)
#
#  block_8_add (Add)              (None, 16, 16, 64)   0           ['block_7_add[0][0]',
#                                                                   'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, 16, 16, 384)  24576       ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNormal  (None, 16, 16, 384)  1536       ['block_9_expand[0][0]']
#  ization)
#
#  block_9_expand_relu (ReLU)     (None, 16, 16, 384)  0           ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (DepthwiseCo  (None, 16, 16, 384)  3456       ['block_9_expand_relu[0][0]']
#  nv2D)
#
#  block_9_depthwise_BN (BatchNor  (None, 16, 16, 384)  1536       ['block_9_depthwise[0][0]']
#  malization)
#
#  block_9_depthwise_relu (ReLU)  (None, 16, 16, 384)  0           ['block_9_depthwise_BN[0][0]']
#
#  block_9_project (Conv2D)       (None, 16, 16, 64)   24576       ['block_9_depthwise_relu[0][0]']
#
#  block_9_project_BN (BatchNorma  (None, 16, 16, 64)  256         ['block_9_project[0][0]']
#  lization)
#
#  block_9_add (Add)              (None, 16, 16, 64)   0           ['block_8_add[0][0]',
#                                                                   'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, 16, 16, 384)  24576       ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchNorma  (None, 16, 16, 384)  1536       ['block_10_expand[0][0]']
#  lization)
#
#  block_10_expand_relu (ReLU)    (None, 16, 16, 384)  0           ['block_10_expand_BN[0][0]']
#
#  block_10_depthwise (DepthwiseC  (None, 16, 16, 384)  3456       ['block_10_expand_relu[0][0]']
#  onv2D)
#
#  block_10_depthwise_BN (BatchNo  (None, 16, 16, 384)  1536       ['block_10_depthwise[0][0]']
#  rmalization)
#
#  block_10_depthwise_relu (ReLU)  (None, 16, 16, 384)  0          ['block_10_depthwise_BN[0][0]']
#
#  block_10_project (Conv2D)      (None, 16, 16, 96)   36864       ['block_10_depthwise_relu[0][0]']
#
#  block_10_project_BN (BatchNorm  (None, 16, 16, 96)  384         ['block_10_project[0][0]']
#  alization)
#
#  block_11_expand (Conv2D)       (None, 16, 16, 576)  55296       ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchNorma  (None, 16, 16, 576)  2304       ['block_11_expand[0][0]']
#  lization)
#
#  block_11_expand_relu (ReLU)    (None, 16, 16, 576)  0           ['block_11_expand_BN[0][0]']
#
#  block_11_depthwise (DepthwiseC  (None, 16, 16, 576)  5184       ['block_11_expand_relu[0][0]']
#  onv2D)
#
#  block_11_depthwise_BN (BatchNo  (None, 16, 16, 576)  2304       ['block_11_depthwise[0][0]']
#  rmalization)
#
#  block_11_depthwise_relu (ReLU)  (None, 16, 16, 576)  0          ['block_11_depthwise_BN[0][0]']
#
#  block_11_project (Conv2D)      (None, 16, 16, 96)   55296       ['block_11_depthwise_relu[0][0]']
#
#  block_11_project_BN (BatchNorm  (None, 16, 16, 96)  384         ['block_11_project[0][0]']
#  alization)
#
#  block_11_add (Add)             (None, 16, 16, 96)   0           ['block_10_project_BN[0][0]',
#                                                                   'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, 16, 16, 576)  55296       ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchNorma  (None, 16, 16, 576)  2304       ['block_12_expand[0][0]']
#  lization)
#
#  block_12_expand_relu (ReLU)    (None, 16, 16, 576)  0           ['block_12_expand_BN[0][0]']
#
#  block_12_depthwise (DepthwiseC  (None, 16, 16, 576)  5184       ['block_12_expand_relu[0][0]']
#  onv2D)
#
#  block_12_depthwise_BN (BatchNo  (None, 16, 16, 576)  2304       ['block_12_depthwise[0][0]']
#  rmalization)
#
#  block_12_depthwise_relu (ReLU)  (None, 16, 16, 576)  0          ['block_12_depthwise_BN[0][0]']
#
#  block_12_project (Conv2D)      (None, 16, 16, 96)   55296       ['block_12_depthwise_relu[0][0]']
#
#  block_12_project_BN (BatchNorm  (None, 16, 16, 96)  384         ['block_12_project[0][0]']
#  alization)
#
#  block_12_add (Add)             (None, 16, 16, 96)   0           ['block_11_add[0][0]',
#                                                                   'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, 16, 16, 576)  55296       ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchNorma  (None, 16, 16, 576)  2304       ['block_13_expand[0][0]']
#  lization)
#
#  block_13_expand_relu (ReLU)    (None, 16, 16, 576)  0           ['block_13_expand_BN[0][0]']
#
#  block_13_pad (ZeroPadding2D)   (None, 17, 17, 576)  0           ['block_13_expand_relu[0][0]']
#
#  block_13_depthwise (DepthwiseC  (None, 8, 8, 576)   5184        ['block_13_pad[0][0]']
#  onv2D)
#
#  block_13_depthwise_BN (BatchNo  (None, 8, 8, 576)   2304        ['block_13_depthwise[0][0]']
#  rmalization)
#
#  block_13_depthwise_relu (ReLU)  (None, 8, 8, 576)   0           ['block_13_depthwise_BN[0][0]']
#
#  block_13_project (Conv2D)      (None, 8, 8, 160)    92160       ['block_13_depthwise_relu[0][0]']
#
#  block_13_project_BN (BatchNorm  (None, 8, 8, 160)   640         ['block_13_project[0][0]']
#  alization)
#
#  block_14_expand (Conv2D)       (None, 8, 8, 960)    153600      ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchNorma  (None, 8, 8, 960)   3840        ['block_14_expand[0][0]']
#  lization)
#
#  block_14_expand_relu (ReLU)    (None, 8, 8, 960)    0           ['block_14_expand_BN[0][0]']
#
#  block_14_depthwise (DepthwiseC  (None, 8, 8, 960)   8640        ['block_14_expand_relu[0][0]']
#  onv2D)
#
#  block_14_depthwise_BN (BatchNo  (None, 8, 8, 960)   3840        ['block_14_depthwise[0][0]']
#  rmalization)
#
#  block_14_depthwise_relu (ReLU)  (None, 8, 8, 960)   0           ['block_14_depthwise_BN[0][0]']
#
#  block_14_project (Conv2D)      (None, 8, 8, 160)    153600      ['block_14_depthwise_relu[0][0]']
#
#  block_14_project_BN (BatchNorm  (None, 8, 8, 160)   640         ['block_14_project[0][0]']
#  alization)
#
#  block_14_add (Add)             (None, 8, 8, 160)    0           ['block_13_project_BN[0][0]',
#                                                                   'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, 8, 8, 960)    153600      ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchNorma  (None, 8, 8, 960)   3840        ['block_15_expand[0][0]']
#  lization)
#
#  block_15_expand_relu (ReLU)    (None, 8, 8, 960)    0           ['block_15_expand_BN[0][0]']
#
#  block_15_depthwise (DepthwiseC  (None, 8, 8, 960)   8640        ['block_15_expand_relu[0][0]']
#  onv2D)
#
#  block_15_depthwise_BN (BatchNo  (None, 8, 8, 960)   3840        ['block_15_depthwise[0][0]']
#  rmalization)
#
#  block_15_depthwise_relu (ReLU)  (None, 8, 8, 960)   0           ['block_15_depthwise_BN[0][0]']
#
#  block_15_project (Conv2D)      (None, 8, 8, 160)    153600      ['block_15_depthwise_relu[0][0]']
#
#  block_15_project_BN (BatchNorm  (None, 8, 8, 160)   640         ['block_15_project[0][0]']
#  alization)
#
#  block_15_add (Add)             (None, 8, 8, 160)    0           ['block_14_add[0][0]',
#                                                                   'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, 8, 8, 960)    153600      ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchNorma  (None, 8, 8, 960)   3840        ['block_16_expand[0][0]']
#  lization)
#
#  block_16_expand_relu (ReLU)    (None, 8, 8, 960)    0           ['block_16_expand_BN[0][0]']
#
#  block_16_depthwise (DepthwiseC  (None, 8, 8, 960)   8640        ['block_16_expand_relu[0][0]']
#  onv2D)
#
#  block_16_depthwise_BN (BatchNo  (None, 8, 8, 960)   3840        ['block_16_depthwise[0][0]']
#  rmalization)
#
#  block_16_depthwise_relu (ReLU)  (None, 8, 8, 960)   0           ['block_16_depthwise_BN[0][0]']
#
#  block_16_project (Conv2D)      (None, 8, 8, 320)    307200      ['block_16_depthwise_relu[0][0]']
#
#  block_16_project_BN (BatchNorm  (None, 8, 8, 320)   1280        ['block_16_project[0][0]']
#  alization)
#
#  Conv_1 (Conv2D)                (None, 8, 8, 1280)   409600      ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalization)  (None, 8, 8, 1280)  5120        ['Conv_1[0][0]']
#
#  out_relu (ReLU)                (None, 8, 8, 1280)   0           ['Conv_1_bn[0][0]']
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________
# last layer output shape:  (None, 8, 8, 1280)

# %%
z = Flatten()(last_layer.output)
z = Dense(1024, activation='relu')(z)
z = Dropout(0.3)(z)
transfer_outputs = Dense(900, activation='softmax')(z)

transfer_model = Model(transfer.input, transfer_outputs)
transfer_model.summary()

transfer_model.compile(optimizer='adam',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_20 (InputLayer)          [(None, 250, 250, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 125, 125, 32  864         ['input_20[0][0]']
#                                 )
#
#  bn_Conv1 (BatchNormalization)  (None, 125, 125, 32  128         ['Conv1[0][0]']
#                                 )
#
#  Conv1_relu (ReLU)              (None, 125, 125, 32  0           ['bn_Conv1[0][0]']
#                                 )
#
#  expanded_conv_depthwise (Depth  (None, 125, 125, 32  288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv_depthwise_BN (Ba  (None, 125, 125, 32  128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              )
#
#  expanded_conv_depthwise_relu (  (None, 125, 125, 32  0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          )                                ]']
#
#  expanded_conv_project (Conv2D)  (None, 125, 125, 16  512        ['expanded_conv_depthwise_relu[0]
#                                 )                                [0]']
#
#  expanded_conv_project_BN (Batc  (None, 125, 125, 16  64         ['expanded_conv_project[0][0]']
#  hNormalization)                )
#
# Epoch 11/20
# 228/228 [==============================] - 125s 546ms/step - loss: 6.2602 - accuracy: 0.0172 - val_loss: 6.3121 - val_accuracy: 0.0158
# Epoch 12/20
# 228/228 [==============================] - 125s 547ms/step - loss: 6.2362 - accuracy: 0.0172 - val_loss: 6.2939 - val_accuracy: 0.0158
# Epoch 13/20
# 228/228 [==============================] - 124s 543ms/step - loss: 6.2215 - accuracy: 0.0173 - val_loss: 6.2785 - val_accuracy: 0.0158
# Epoch 14/20
# 228/228 [==============================] - 124s 544ms/step - loss: 6.1973 - accuracy: 0.0172 - val_loss: 6.2656 - val_accuracy: 0.0158
# Epoch 15/20
# 228/228 [==============================] - 124s 545ms/step - loss: 6.1817 - accuracy: 0.0172 - val_loss: 6.2547 - val_accuracy: 0.0158
# Epoch 16/20
# 228/228 [==============================] - 124s 545ms/step - loss: 6.1685 - accuracy: 0.0172 - val_loss: 6.2458 - val_accuracy: 0.0158
# Epoch 17/20
# 228/228 [==============================] - ETA: 0s - loss: 6.1571 - accuracy: 0.0172
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/barti/deep/tenorflow-projects/flowers_kagle.ipynb Cell 19' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000021?line=0'>1</a> history_transfer = transfer_model.fit(training_data,
#       <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000021?line=1'>2</a>                                       epochs=20,
#       <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000021?line=2'>3</a>                                       validation_data=validation_data)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1445, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1431 if getattr(self, '_eval_data_handler', None) is None:
#    1432   self._eval_data_handler = data_adapter.get_data_handler(
#    1433       x=val_x,
#    1434       y=val_y,
#    (...)
#    1443       model=self,
#    1444       steps_per_execution=self._steps_per_execution)
# -> 1445 val_logs = self.evaluate(
#    1446     x=val_x,
#    1447     y=val_y,
#    1448     sample_weight=val_sample_weight,
#    1449     batch_size=validation_batch_size or batch_size,
#    1450     steps=validation_steps,
#    1451     callbacks=callbacks,
#    1452     max_queue_size=max_queue_size,
#    1453     workers=workers,
#    1454     use_multiprocessing=use_multiprocessing,
#    1455     return_dict=True,
#    1456     _use_cached_eval_dataset=True)
#    1457 val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1458 epoch_logs.update(val_logs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1756, in Model.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1754 with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1755   callbacks.on_test_batch_begin(step)
# -> 1756   tmp_logs = self.test_function(iterator)
#    1757   if data_handler.should_sync:
#    1758     context.async_wait()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# As we can se for now every architecture is failing to learn.
# We are going to try for MobileNet architecture to train from scratch on our dataset.
# Models are doing bad, because we have 900 and only 22 000 examples, even with data augumentation we are doing pretty poorly.

# %% [markdown]
# #### ResNet50 Architecture

# %%
from keras.applications import ResNet50V2

#Load ResNet50 model without weights to train from scratch
resnet = ResNet50V2(include_top=False,
                    input_shape=(250,  250, 3),
                    weights=None)


#Get specified layer from ResNet model
last_resnet_layer = resnet.get_layer('post_bn')
print('last layer output shape: ', last_layer.output_shape)


y = Flatten()(last_resnet_layer.output)
y = Dense(1024, activation='relu')(y)
resnet_output = Dense(900, activation='softmax')(y)

resnet_model = Model(resnet.input, resnet_output)

resnet_model.summary()
# Out:
# last layer output shape:  (None, 8, 8, 1280)
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_23 (InputLayer)          [(None, 250, 250, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 256, 256, 3)  0           ['input_23[0][0]']
#
#  conv1_conv (Conv2D)            (None, 125, 125, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 127, 127, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 63, 63, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 63, 63, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 63, 63, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 63, 63, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 65, 65, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 63, 63, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 63, 63, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 63, 63, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 63, 63, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 63, 63, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 63, 63, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 63, 63, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 65, 65, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 63, 63, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 63, 63, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 63, 63, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 63, 63, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 63, 63, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 63, 63, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 63, 63, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 63, 63, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 65, 65, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_53 (MaxPooling2D  (None, 32, 32, 256)  0          ['conv2_block2_out[0][0]']
#  )
#
#  conv2_block3_3_conv (Conv2D)   (None, 32, 32, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 32, 32, 256)  0           ['max_pooling2d_53[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 32, 32, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 32, 32, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 32, 32, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 32, 32, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 32, 32, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 32, 32, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 32, 32, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 32, 32, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 32, 32, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 32, 32, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 32, 32, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 32, 32, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_54 (MaxPooling2D  (None, 16, 16, 512)  0          ['conv3_block3_out[0][0]']
#  )
#
#  conv3_block4_3_conv (Conv2D)   (None, 16, 16, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 16, 16, 512)  0           ['max_pooling2d_54[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 16, 16, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 16, 16, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 16, 16, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 16, 16, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 16, 16, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 16, 16, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 16, 16, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 16, 16, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 8, 8, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_55 (MaxPooling2D  (None, 8, 8, 1024)  0           ['conv4_block5_out[0][0]']
#  )
#
#  conv4_block6_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 8, 8, 1024)   0           ['max_pooling2d_55[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 8, 8, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 8, 8, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 8, 8, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 10, 10, 512)  0          ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 8, 8, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 8, 8, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 8, 8, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 8, 8, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 8, 8, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 10, 10, 512)  0          ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 8, 8, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 8, 8, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 8, 8, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 8, 8, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 10, 10, 512)  0          ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 8, 8, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 8, 8, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 8, 8, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  flatten_14 (Flatten)           (None, 131072)       0           ['post_bn[0][0]']
#
#  dense_52 (Dense)               (None, 1024)         134218752   ['flatten_14[0][0]']
#
#  dense_53 (Dense)               (None, 900)          922500      ['dense_52[0][0]']
#
# ==================================================================================================
# Total params: 158,706,052
# Trainable params: 158,660,612
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
resnet_model.compile(optimizer='adam',
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

# %%
history_resnet = transfer_model.fit(training_data,
                                      epochs=20,
                                      validation_data=validation_data)
# Out:
# Epoch 1/20
# 228/228 [==============================] - 127s 556ms/step - loss: 6.1475 - accuracy: 0.0172 - val_loss: 6.2324 - val_accuracy: 0.0158
# Epoch 2/20
# 228/228 [==============================] - 126s 553ms/step - loss: 6.1393 - accuracy: 0.0172 - val_loss: 6.2277 - val_accuracy: 0.0158
# Epoch 3/20
# 228/228 [==============================] - 124s 544ms/step - loss: 6.1324 - accuracy: 0.0172 - val_loss: 6.2238 - val_accuracy: 0.0158
# Epoch 4/20
# 228/228 [==============================] - 125s 548ms/step - loss: 6.1265 - accuracy: 0.0172 - val_loss: 6.2208 - val_accuracy: 0.0158
# Epoch 5/20
# 228/228 [==============================] - 125s 550ms/step - loss: 6.1215 - accuracy: 0.0172 - val_loss: 6.2184 - val_accuracy: 0.0158
# Epoch 6/20
# 228/228 [==============================] - 125s 547ms/step - loss: 6.1172 - accuracy: 0.0172 - val_loss: 6.2165 - val_accuracy: 0.0158
# Epoch 7/20
# 228/228 [==============================] - 125s 550ms/step - loss: 6.1135 - accuracy: 0.0172 - val_loss: 6.2151 - val_accuracy: 0.0158
# Epoch 8/20
# 228/228 [==============================] - 125s 547ms/step - loss: 6.1104 - accuracy: 0.0172 - val_loss: 6.2141 - val_accuracy: 0.0158
# Epoch 9/20
# 228/228 [==============================] - 125s 550ms/step - loss: 6.1076 - accuracy: 0.0172 - val_loss: 6.2133 - val_accuracy: 0.0158
# Epoch 10/20
#  28/228 [==>...........................] - ETA: 1:43 - loss: 6.1210 - accuracy: 0.0185
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/barti/deep/tenorflow-projects/flowers_kagle.ipynb Cell 24' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000026?line=0'>1</a> history_resnet = transfer_model.fit(training_data,
#       <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000026?line=1'>2</a>                                       epochs=20,
#       <a href='vscode-notebook-cell:/home/barti/deep/tenorflow-projects/flowers_kagle.ipynb#ch0000026?line=2'>3</a>                                       validation_data=validation_data)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
